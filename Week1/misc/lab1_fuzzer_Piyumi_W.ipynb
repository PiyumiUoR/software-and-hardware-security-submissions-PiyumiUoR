# %%
import random
import time

def delete_random_character(s: str) -> str:
    if s == "":
        return s

    pos = random.randint(0, len(s) - 1)
    return s[:pos] + s[pos + 1:]

def insert_random_character(s: str) -> str:
    
    pos = random.randint(0, len(s))
    random_character = chr(random.randrange(32, 127))
    return s[:pos] + random_character + s[pos:]

def flip_random_character(s):
    
    if s == "":
        return s

    pos = random.randint(0, len(s) - 1)
    c = s[pos]
    bit = 1 << random.randint(0, 6)
    new_c = chr(ord(c) ^ bit)
    return s[:pos] + new_c + s[pos + 1:]

def mutate(s: str) -> str:
    
    mutators = [
        delete_random_character,
        insert_random_character,
        flip_random_character
    ]
    mutator = random.choice(mutators)
    
    return mutator(s)

seed_input = "http://www.google.com/search?q=fuzzing"
# mutations = 5
inp = seed_input

### Running the program for a specific time period

duration = 0.1
start_at = time.time()
i = 0
while True:
    if time.time() - start_at <= duration:
            i += 1
            print(i, mutate(inp))
            inp = seed_input
            
    if time.time() - start_at >= duration:
        break 
  
### Running the program for a specific mutation count
# for i in range(mutations):
#     if i <= 10:
#         print(i, "mutations:", repr(inp))
#         inp = mutate(inp)
# Out:
# 1 http://ww.google.com/search?q=fuzzing
# 2 http://www.google.com/s%arch?q=fuzzing
# 3 http://www.googlecom/search?q=fuzzing
# 4 http://www.google.com/earch?q=fuzzing
# 5 http://www.google.com/searc8h?q=fuzzing
# 6 http://www.)google.com/search?q=fuzzing
# 7 http:/7/www.google.com/search?q=fuzzing
# 8 http://ww.google.com/search?q=fuzzing
# 9 htatp://www.google.com/search?q=fuzzing
# 10 http://www.google.com/search?q=Gfuzzing
# 11 http://www.google.com/sarch?q=fuzzing
# 12 http:/www.google.com/search?q=fuzzing
# 13 http://wwwngoogle.com/search?q=fuzzing
# 14 http://www.google.com/search?qfuzzing
# 15 ttp://www.google.com/search?q=fuzzing
# 16 http://www.google.com/search?q=Afuzzing
# 17 http://wgw.google.com/search?q=fuzzing
# 18 http://www.google.com/search?qfuzzing
# 19 http://www.google.som/search?q=fuzzing
# 20 http://www.google.com/search?q=fuzjing
# 21 http://www.google.com/search?q=fuzzin
# 22 http://www.google.coo/search?q=fuzzing
# 23 http://www.google.com/search?q=fuzzig
# 24 http://www.g=oogle.com/search?q=fuzzing
# 25 http//www.google.com/search?q=fuzzing
# 26 http://www.google.cm/search?q=fuzzing
# 27 http://www.google.cm/search?q=fuzzing
# 28 http:/'www.google.com/search?q=fuzzing
# 29 http://www.google.com/searJch?q=fuzzing
# 30 http://www.gogle.com/search?q=fuzzing
# 31 http:/www.google.com/search?q=fuzzing
# 32 -http://www.google.com/search?q=fuzzing
# 33 http://www.google.com/qearch?q=fuzzing
# 34 http://www.googl.com/search?q=fuzzing
# 35 http://www.google.col/search?q=fuzzing
# 36 http://www.google.com/qearch?q=fuzzing
# 37 http://www.google.com/Search?q=fuzzing
# 38 http://www.google.com/search?s=fuzzing
# 39 http://www.google.com/sdarch?q=fuzzing
# 40 http://www .google.com/search?q=fuzzing
# 41 http://www.google.Ecom/search?q=fuzzing
# 42 http://www.googleC.com/search?q=fuzzing
# 43 http://www.google.com/3earch?q=fuzzing
# 44 http://www.google.co/search?q=fuzzing
# 45 http:./www.google.com/search?q=fuzzing
# 46 htup://www.google.com/search?q=fuzzing
# 47 http://www.google.com/3earch?q=fuzzing
# 48 htKtp://www.google.com/search?q=fuzzing
# 49 http://www.google.comsearch?q=fuzzing
# 50 http://ww~w.google.com/search?q=fuzzing
# 51 http://www.oogle.com/search?q=fuzzing
# 52 http://ww7.google.com/search?q=fuzzing
# 53 http://www.goog|e.com/search?q=fuzzing
# 54 http://www.google.com/search?qfuzzing
# 55 http://wwwgoogle.com/search?q=fuzzing
# 56 http://www.google.com/search?q=fguzzing
# 57 http://ww.google.com/search?q=fuzzing
# 58 http://www.google.com/search?q=fuz=zing
# 59 http://www.google.comQ/search?q=fuzzing
# 60 http://www.google.com/search?q=fuzzi~ng
# 61 http://www.google.com/search?q=fuzzin_g
# 62 http://www.gogle.com/search?q=fuzzing
# 63 httqp://www.google.com/search?q=fuzzing
# 64 http://www.google.com/search?q=fuzing
# 65 http://www.google.comsearch?q=fuzzing
# 66 http://www.google.com/search?y=fuzzing
# 67 http://www.coogle.com/search?q=fuzzing
# 68 h"ttp://www.google.com/search?q=fuzzing
# 69 xttp://www.google.com/search?q=fuzzing
# 70 http://ww.google.com/search?q=fuzzing
# 71 http://www.google.com/seerch?q=fuzzing
# 72 http://www.google.com/serch?q=fuzzing
# 73 http://www.google.com/search?q=fuzing
# 74 http://www.google.com/searchq=fuzzing
# 75 http://www.googley.com/search?q=fuzzing
# 76 http://www.google.com/search?q=fuzzng
# 77 http:I//www.google.com/search?q=fuzzing
# 78 htvp://www.google.com/search?q=fuzzing
# 79 http://www.google.com/search?q=fujzing
# 80 http://www.google.com/seaRch?q=fuzzing
# 81 http://www.google.com/search?q=fuzzig
# 82 http:9//www.google.com/search?q=fuzzing
# 83 http://www.google.com/search?q=fzzing
# 84 hzttp://www.google.com/search?q=fuzzing
# 85 http://www.google.com/searcwh?q=fuzzing
# 86 http://www.google.com/search?q=fNuzzing
# 87 http://www.google.com/search?a=fuzzing
# 88 htp://www.google.com/search?q=fuzzing
# 89 hptp://www.google.com/search?q=fuzzing
# 90 http://www.gokgle.com/search?q=fuzzing
# 91 http://www.google.com/search?q=fuzziCng
# 92 http://www.google.com/searh?q=fuzzing
# 93 http://www.google.com/search?q=fuzing
# 94 http://www.google.co/search?q=fuzzing
# 95 http>//www.google.com/search?q=fuzzing
# 96 http://www.google.com/earch?q=fuzzing
# 97 http://7ww.google.com/search?q=fuzzing
# 98 http://www.oogle.com/search?q=fuzzing
# 99 http://www.googlg.com/search?q=fuzzing
# 100 http://www.google.com/searcGh?q=fuzzing
# 101 http://uww.google.com/search?q=fuzzing
# 102 http://www.oogle.com/search?q=fuzzing
# 103 http://www.google.com/search?q=fuzzng
# 104 http://www.google.com/search?q$=fuzzing
# 105 http://www.googl7e.com/search?q=fuzzing
# 106 http:W//www.google.com/search?q=fuzzing
# 107 http://www.gogle.com/search?q=fuzzing
# 108 http://www.googlm.com/search?q=fuzzing
# 109 http://www.google.com/search?q=f5zzing
# 110 http://www.google.com/search?q=f}zzing
# 111 http://www.oogle.com/search?q=fuzzing
# 112 http://www.goocle.com/search?q=fuzzing
# 113 http://www.googl.com/search?q=fuzzing
# 114 http://www.gVoogle.com/search?q=fuzzing
# 115 http://www.oogle.com/search?q=fuzzing
# 116 http://www.google.com/search?q=fuz:ing
# 117 http//www.google.com/search?q=fuzzing
# 118 http://wVww.google.com/search?q=fuzzing
# 119 http://www.google.com/search??q=fuzzing
# 120 http://www.google.aom/search?q=fuzzing
# 121 http://wwww.google.com/search?q=fuzzing
# 122 http://www.goog_le.com/search?q=fuzzing
# 123 http://www.google.com/seasch?q=fuzzing
# 124 http://www.google.com/sEearch?q=fuzzing
# 125 http://ww.google.com/search?q=fuzzing
# 126 http://www.google.som/search?q=fuzzing
# 127 http://www.googlecom/search?q=fuzzing
# 128 http://www.google.com/se2arch?q=fuzzing
# 129 http://www.google.com/search?q=fuxzing
# 130 http://www.goo'le.com/search?q=fuzzing
# 131 http://www.google.com/sarch?q=fuzzing
# 132 http://www.googe.com/search?q=fuzzing
# 133 http://www.google.com/secrch?q=fuzzing
# 134 http://www.google.com/search?q=fuzzin'
# 135 http://www.google.com/seaQrch?q=fuzzing
# 136 ttp://www.google.com/search?q=fuzzing
# 137 hTtp://www.google.com/search?q=fuzzing
# 138 http://www.google.com/serch?q=fuzzing
# 139 lhttp://www.google.com/search?q=fuzzing
# 140 http://www.gXoogle.com/search?q=fuzzing
# 141 http://www.google.com/search?q=fuzzi~g
# 142 http://www.google.com/searc?q=fuzzing
# 143 http://www.google*com/search?q=fuzzing
# 144 http://www.google.com/search?q=fuzing
# 145 http://www.google.com/search?y=fuzzing
# 146 http://www.google.com/search?q=fuzzyng
# 147 http:/www.google.com/search?q=fuzzing
# 148 h>ttp://www.google.com/search?q=fuzzing
# 149 http://www.google,com/search?q=fuzzing
# 150 http://www.google.com/search?q=fuzZing
# 151 http://www.googe.com/search?q=fuzzing
# 152 http://www.google.comsearch?q=fuzzing
# 153 http://www.google.com/search?q=-fuzzing
# 154 http://www.gotogle.com/search?q=fuzzing
# 155 http://www.goo^gle.com/search?q=fuzzing
# 156 http://www.google.com/\search?q=fuzzing
# 157 http://www.google.com/earch?q=fuzzing
# 158 http://www.google.com/search?q=fuzzinjg
# 159 http://www.google.com/searcrh?q=fuzzing
# 160 http://www.google.com/serch?q=fuzzing
# 161 http://www.google.coe/search?q=fuzzing
# 162 http://www.googe.com/search?q=fuzzing
# 163 http://www.google.com/sezarch?q=fuzzing
# 164 http://www9.google.com/search?q=fuzzing
# 165 htitp://www.google.com/search?q=fuzzing
# 166 http://www.oogle.com/search?q=fuzzing
# 167 http://www.google.com/searh?q=fuzzing
# 168 http8//www.google.com/search?q=fuzzing
# 169 http://www.google.com/search?q=fuzzing@
# 170 http://www.google.c/m/search?q=fuzzing
# 171 http://www.google.com/search?q=fuCzzing
# 172 http://www.googld.com/search?q=fuzzing
# 173 http://www.googLe.com/search?q=fuzzing
# 174 http://www.oogle.com/search?q=fuzzing
# 175 httpm://www.google.com/search?q=fuzzing
# 176 http://www.google.com/search?q9fuzzing
# 177 http://ww.google.com/search?q=fuzzing
# 178 http://www.googne.com/search?q=fuzzing
# 179 http://www.google.com/search?q=uzzing
# 180 http://www.google.com/qearch?q=fuzzing
# 181 http://www.google.com/searc?q=fuzzing
# 182 http://www.gPoogle.com/search?q=fuzzing
# 183 http://www.google.com/search?=fuzzing
# 184 http://www.google.comsearch?q=fuzzing
# 185 http://www.google.com/search?Pq=fuzzing
# 186 httpB://www.google.com/search?q=fuzzing
# 187 http://www.google.com/search?=fuzzing
# 188 http://www.google.com/search?q=uzzing
# 189 http://www.google>com/search?q=fuzzing
# 190 http://www.google.com/searchq=fuzzing
# 191 http:/r/www.google.com/search?q=fuzzing
# 192 http://www.gogle.com/search?q=fuzzing
# 193 http://www.google.com/search?q=fuzzyng
# 194 http://www.google.comB/search?q=fuzzing
# 195 http://www.google.co/search?q=fuzzing
# 196 jttp://www.google.com/search?q=fuzzing
# 197 http://www.google.com/search?q=fuz?zing
# 198 http://wwwgoogle.com/search?q=fuzzing
# 199 http://www.google.com/search?q=fuzzin)g
# 200 http://www.google.om/search?q=fuzzing
# 201 http://www.googlse.com/search?q=fuzzing
# 202 http://www.google.com/search?q=fzzing
# 203 http://www>google.com/search?q=fuzzing
# 204 http://www.google.com/search?qfuzzing
# 205 http://www.google.com/search?u=fuzzing
# 206 http://www.google.comb/search?q=fuzzing
# 207 http://www.google.com/search?q=fuczzing
# 208 http://www.google.com/search?q=fuzzingg
# 209 http://www.google.com/gsearch?q=fuzzing
# 210 http://awww.google.com/search?q=fuzzing
# 211 hTtp://www.google.com/search?q=fuzzing
# 212 http://www.googLe.com/search?q=fuzzing
# 213 htt0://www.google.com/search?q=fuzzing
# 214 http://www.googcle.com/search?q=fuzzing
# 215 http://www.google.com/search?q;=fuzzing
# 216 http://www.google.com/search?q=fzzing
# 217 http://www.gogle.com/search?q=fuzzing
# 218 htp://www.google.com/search?q=fuzzing
# 219 http://www.google.com/search?q=fuzz%ing
# 220 http://www.googlu.com/search?q=fuzzing
# 221 4http://www.google.com/search?q=fuzzing
# 222 http:=//www.google.com/search?q=fuzzing
# 223 http://www.google.cm/search?q=fuzzing
# 224 http://www.google.com/searc?q=fuzzing
# 225 http://www.google.com/sear<ch?q=fuzzing
# 226 http://wwwgoogle.com/search?q=fuzzing
# 227 Ihttp://www.google.com/search?q=fuzzing
# 228 http://www.google.co8m/search?q=fuzzing
# 229 http:+/www.google.com/search?q=fuzzing
# 230 http://www.goole.com/search?q=fuzzing
# 231 http://www.google.Com/search?q=fuzzing
# 232 http://www.goole.com/search?q=fuzzing
# 233 http://www.eoogle.com/search?q=fuzzing
# 234 http:/7/www.google.com/search?q=fuzzing
# 235 http://www.gogle.com/search?q=fuzzing
# 236 http://www.google.com/search?q=fuzzirng
# 237 yhttp://www.google.com/search?q=fuzzing
# 238 http://www.google.com/search?q=Nfuzzing
# 239 http://www.google.com/search?q=fzzing
# 240 http:/www.google.com/search?q=fuzzing
# 241 http://www.goocle.com/search?q=fuzzing
# 242 http://www.googhle.com/search?q=fuzzing
# 243 http://www.gogle.com/search?q=fuzzing
# 244 http://www.googhe.com/search?q=fuzzing
# 245 http://www.google.com/search?q=fuzzinf
# 246 http://www.goole.com/search?q=fuzzing
# 247 http://www.woogle.com/search?q=fuzzing
# 248 http://www.google.com/search?1q=fuzzing
# 249 http://www.google.co/search?q=fuzzing
# 250 http://www.google.comosearch?q=fuzzing
# 251 http://www.google.com/search?q=fu{zing
# 252 http://www.google.com/search?q=fuzzi=ng
# 253 http://www.google.com/search?q=fuzzin
# 254 http://www.google.com/search?q=duzzing
# 255 http://www.google.com/search/q=fuzzing
# 256 httq://www.google.com/search?q=fuzzing
# 257 htp://www.google.com/search?q=fuzzing
# 258 htpp://www.google.com/search?q=fuzzing
# 259 http://ww.google.com/search?q=fuzzing
# 260 http://www.g/ogle.com/search?q=fuzzing
# 261 http://www.google.com/search?q=uzzing
# 262 http://www.goRogle.com/search?q=fuzzing
# 263 http://www.'oogle.com/search?q=fuzzing
# 264 http://wfww.google.com/search?q=fuzzing
# 265 htpp://www.google.com/search?q=fuzzing
# 266 http://ww.google.com/search?q=fuzzing
# 267 http://www.google.co-/search?q=fuzzing
# 268 http://ww.google.com/search?q=fuzzing
# 269 http://www.googe.com/search?q=fuzzing
# 270 http://www.google.com/search?q=fuzzilg
# 271 http://www.gOogle.com/search?q=fuzzing
# 272 http://www.googlm.com/search?q=fuzzing
# 273 http://www.google.com/search?=fuzzing
# 274 h;ttp://www.google.com/search?q=fuzzing
# 275 http://ww.google.com/search?q=fuzzing
# 276 http://wvw.google.com/search?q=fuzzing
# 277 http://www.google.com/search?q=fuzzig

# %%
import random
import time

def delete_random_character(s: str) -> str:
    
    if s == "":
        return s

    pos = random.randint(0, len(s) - 1)
    return s[:pos] + s[pos + 1:]

def insert_random_character(s: str) -> str:
    
    pos = random.randint(0, len(s))
    random_character = chr(random.randrange(32, 127))
    return s[:pos] + random_character + s[pos:]

def flip_random_character(s):
    
    if s == "":
        return s

    pos = random.randint(0, len(s) - 1)
    c = s[pos]
    bit = 1 << random.randint(0, 6)
    new_c = chr(ord(c) ^ bit)
    return s[:pos] + new_c + s[pos + 1:]

def mutate(s: str) -> str:
    
    mutators = [
        delete_random_character,
        insert_random_character,
        flip_random_character
    ]
    mutator = random.choice(mutators)
    
    return mutator(s)

seed_input = "http://www.google.com/search?q=fuzzing"
mutations = 20
inp = seed_input

### Running the program for a specific time period

# duration = 0.1
# start_at = time.time()
# i = 0
# while True:
#     if time.time() - start_at <= duration:
#             i += 1
#             print(i, repr(inp))
#             inp = mutate(inp)
            
#     if time.time() - start_at >= duration:
#         break 
  
### Running the program for a specific mutation count
for i in range(mutations):
    if i <= mutations:
        print(i, "mutations:", mutate(inp))
        inp = seed_input
# Out:
# 0 mutations: http://www.google.com/search?qfuzzing
# 1 mutations: http://www.google.coe/search?q=fuzzing
# 2 mutations: http://www.google.com/search?q=fuzzi.g
# 3 mutations: http://www.google.Com/search?q=fuzzing
# 4 mutations: http://www.googe.com/search?q=fuzzing
# 5 mutations: http://www.google.com/searchq=fuzzing
# 6 mutations: http://www.google.com/separch?q=fuzzing
# 7 mutations: http:U//www.google.com/search?q=fuzzing
# 8 mutations: http://www.google.com/search?q=Gfuzzing
# 9 mutations: htp://www.google.com/search?q=fuzzing
# 10 mutations: http://www.google.com/search?q=fuazzing
# 11 mutations: http://wwbw.google.com/search?q=fuzzing
# 12 mutations: http://www.google.com/search/q=fuzzing
# 13 mutations: http://www.gooMgle.com/search?q=fuzzing
# 14 mutations: http://www.googne.com/search?q=fuzzing
# 15 mutations: http://www.google.com/search?p=fuzzing
# 16 mutations: http://www.google.com/se=arch?q=fuzzing
# 17 mutations: http://www.google.com/search?vq=fuzzing
# 18 mutations: http://www.gogle.com/search?q=fuzzing
# 19 mutations: http://www.google.com/s{earch?q=fuzzing

# %%
import re

def validate_url(url):
    pattern = r'^(http|https|ftp)://([\w.-]+)(/[\w./]*)?(\?[\w=&-]+)?(#\w+)?$'
    if re.match(pattern, url):
        return True
    else:
        return False


url = input("Input the URL: ")
print(f"The URL is {validate_url(url)}")
# Out:
# Input the URL:  http://www.google.com/search?q=fuzzing
# The URL is True

# %%
import re

def validate_url(url):
    pattern = r'^(http|https|ftp)://([\w.-]+)(/[\w./]*)?(\?[\w=&-]+)?(#\w+)?$'
    if re.match(pattern, url):
        return True
    else:
        return False


url = input("Input the URL: ")
print(f"The URL is {validate_url(url)}")
# Out:
# Input the URL:  http://w\x7fw.googlPe.com?%seach?qfuzzing
# The URL is False

# %%
import re

def validate_url(url):
    pattern = r'^(http|https|ftp)://([\w.-]+)(/[\w./]*)?(\?[\w=&-]+)?(#\w+)?$'
    if re.match(pattern, url):
        return True
    else:
        return False
    
mutations1 = 'http://www.google.com/search?qfuzzing'
mutations2 = 'http://www.google.coe/search?q=fuzzing'
mutations3 = 'http://www.google.com/search?q=fuzzi.g'
mutations4 = 'http://www.google.Com/search?q=fuzzing'
mutations5 = 'http://www.googe.com/search?q=fuzzing'
mutations6 = 'http://www.google.com/searchq=fuzzing'
mutations7 = 'http://www.google.com/separch?q=fuzzing'
mutations8 = 'http:U//www.google.com/search?q=fuzzing'
mutations9 = 'http://www.google.com/search?q=Gfuzzing'
mutations10 = 'htp://www.google.com/search?q=fuzzing'
mutations11 = 'http://www.google.com/search?q=fuazzing'
mutations12 = 'http://wwbw.google.com/search?q=fuzzing'
mutations13 = 'http://www.google.com/search/q=fuzzing'
mutations14 = 'http://www.gooMgle.com/search?q=fuzzing'
mutations15 = 'http://www.googne.com/search?q=fuzzing'
mutations16 = 'http://www.google.com/search?p=fuzzing'
mutations17 = 'http://www.google.com/se=arch?q=fuzzing'
mutations18 = 'http://www.google.com/search?vq=fuzzing'
mutations19 = 'http://www.gogle.com/search?q=fuzzing'
mutations20 = 'http://www.google.com/s{earch?q=fuzzing'

print(f"The URL is {validate_url(mutations1)}")
print(f"The URL is {validate_url(mutations2)}")
print(f"The URL is {validate_url(mutations3)}")
print(f"The URL is {validate_url(mutations4)}")
print(f"The URL is {validate_url(mutations5)}")
print(f"The URL is {validate_url(mutations6)}")
print(f"The URL is {validate_url(mutations7)}")
print(f"The URL is {validate_url(mutations8)}")
print(f"The URL is {validate_url(mutations9)}")
print(f"The URL is {validate_url(mutations10)}")
print(f"The URL is {validate_url(mutations11)}")
print(f"The URL is {validate_url(mutations12)}")
print(f"The URL is {validate_url(mutations13)}")
print(f"The URL is {validate_url(mutations14)}")
print(f"The URL is {validate_url(mutations15)}")
print(f"The URL is {validate_url(mutations16)}")
print(f"The URL is {validate_url(mutations17)}")
print(f"The URL is {validate_url(mutations18)}")
print(f"The URL is {validate_url(mutations19)}")
print(f"The URL is {validate_url(mutations20)}")
# Out:
# The URL is True
# The URL is True
# The URL is False
# The URL is True
# The URL is True
# The URL is False
# The URL is True
# The URL is False
# The URL is True
# The URL is False
# The URL is True
# The URL is True
# The URL is False
# The URL is True
# The URL is True
# The URL is True
# The URL is False
# The URL is True
# The URL is True
# The URL is False

# %%
import random
import time
import re

def delete_random_character(s: str) -> str:
    
    if s == "":
        return s

    pos = random.randint(0, len(s) - 1)
    return s[:pos] + s[pos + 1:]

def insert_random_character(s: str) -> str:
    
    pos = random.randint(0, len(s))
    random_character = chr(random.randrange(32, 127))
    return s[:pos] + random_character + s[pos:]

def flip_random_character(s):
    
    if s == "":
        return s

    pos = random.randint(0, len(s) - 1)
    c = s[pos]
    bit = 1 << random.randint(0, 6)
    new_c = chr(ord(c) ^ bit)
    return s[:pos] + new_c + s[pos + 1:]

def mutate(s: str) -> str:
    
    mutators = [
        delete_random_character,
        insert_random_character,
        flip_random_character
    ]
    mutator = random.choice(mutators)
    
    return mutator(s)

def validate_url(url):
    pattern = r'^(http|https|ftp)://([\w.-]+)(/[\w./]*)?(\?[\w=&-]+)?(#\w+)?$'
    if re.match(pattern, url):
        return True
    else:
        return False

def urlFuzzer(noOfTests):
    
    seed_input = "http://www.google.com/search?q=fuzzing"
    # mutations = 20
    inp = seed_input
    crashes = 0

    for i in range(noOfTests):
        if i <= noOfTests:
            inp = mutate(inp)
            # print("Test case ", (i+1), ": ", repr(inp))
            
            if not validate_url(inp):
                crashes += 1
                print("A crash occured in " + str(i+1))
                print("The input is: ", inp)
            inp = seed_input
    
    print("The total crash count is: ", crashes)

if __name__ == "__main__":
    noOfTests = int(input("Number of test cases? "))
    urlFuzzer(noOfTests)
# Out:
# Number of test cases?  100
# A crash occured in 1
# The input is:  http://www.google.com/se arch?q=fuzzing
# A crash occured in 3
# The input is:  http://www.googl@e.com/search?q=fuzzing
# A crash occured in 6
# The input is:  http:/www.google.com/search?q=fuzzing
# A crash occured in 8
# The input is:  http://www.google.com/sear#h?q=fuzzing
# A crash occured in 11
# The input is:  http://www.google.com/searchq=fuzzing
# A crash occured in 13
# The input is:  htp://www.google.com/search?q=fuzzing
# A crash occured in 15
# The input is:  http://www.google.com/search?%q=fuzzing
# A crash occured in 18
# The input is:  http://www.google.com/searc(?q=fuzzing
# A crash occured in 25
# The input is:  http://www.google.com/search>q=fuzzing
# A crash occured in 28
# The input is:  http://www.google.com%/search?q=fuzzing
# A crash occured in 31
# The input is:  http://www.google.com/search?q=fuz}zing
# A crash occured in 38
# The input is:  jttp://www.google.com/search?q=fuzzing
# A crash occured in 41
# The input is:  http://www.google.com/search?q=fu]zzing
# A crash occured in 49
# The input is:  htt*p://www.google.com/search?q=fuzzing
# A crash occured in 53
# The input is:  http://www.google.com/search?q=fuz)zing
# A crash occured in 56
# The input is:  http:///www.google.com/search?q=fuzzing
# A crash occured in 58
# The input is:  http://www.google.com/searchq=fuzzing
# A crash occured in 59
# The input is:  http://www.goog}le.com/search?q=fuzzing
# A crash occured in 60
# The input is:  htdp://www.google.com/search?q=fuzzing
# A crash occured in 63
# The input is:  http://www.google.com/search7q=fuzzing
# A crash occured in 65
# The input is:  http://www.google.com/(search?q=fuzzing
# A crash occured in 70
# The input is:  http://www.google.com/search?q=fu'zzing
# A crash occured in 71
# The input is:  http*//www.google.com/search?q=fuzzing
# A crash occured in 75
# The input is:  http://www.goog^le.com/search?q=fuzzing
# A crash occured in 78
# The input is:  http://wwwgoogle.com/search?q=fuzzing
# A crash occured in 79
# The input is:  http://w"ww.google.com/search?q=fuzzing
# A crash occured in 86
# The input is:  jttp://www.google.com/search?q=fuzzing
# A crash occured in 87
# The input is:  http://www.google.com/se`rch?q=fuzzing
# A crash occured in 88
# The input is:  http:/?www.google.com/search?q=fuzzing
# A crash occured in 90
# The input is:  http://www.goog,e.com/search?q=fuzzing
# A crash occured in 92
# The input is:  http://www.google.com/s"earch?q=fuzzing
# A crash occured in 93
# The input is:  http://www.google.com/searchq=fuzzing
# A crash occured in 95
# The input is:  httP://www.google.com/search?q=fuzzing
# A crash occured in 98
# The input is:  (ttp://www.google.com/search?q=fuzzing
# A crash occured in 99
# The input is:  http7://www.google.com/search?q=fuzzing
# The total crash count is:  35

# %%
import random
import time
import re

def delete_random_character(s: str) -> str:
    
    if s == "":
        return s

    pos = random.randint(0, len(s) - 1)
    return s[:pos] + s[pos + 1:]

def insert_random_character(s: str) -> str:
    
    pos = random.randint(0, len(s))
    random_character = chr(random.randrange(32, 127))
    return s[:pos] + random_character + s[pos:]

def flip_random_character(s):
    
    if s == "":
        return s

    pos = random.randint(0, len(s) - 1)
    c = s[pos]
    bit = 1 << random.randint(0, 6)
    new_c = chr(ord(c) ^ bit)
    return s[:pos] + new_c + s[pos + 1:]

def mutate(s: str) -> str:
    
    mutators = [
        delete_random_character,
        insert_random_character,
        flip_random_character
    ]
    mutator = random.choice(mutators)
    
    return mutator(s)

def validate_url(url):
    pattern = r'^(http|https|ftp)://([\w.-]+)(/[\w./]*)?(\?[\w=&-]+)?(#\w+)?$'
    if re.match(pattern, url):
        return True
    else:
        return False

def urlFuzzer(noOfTests):
    
    seed_input = "http://www.google.com/search?q=fuzzing"
    # mutations = 20
    inp = seed_input
    crashes = 0

    for i in range(noOfTests):
        if i <= noOfTests:
            inp = mutate(inp)
            # print("Test case ", (i+1), ": ", repr(inp))
            
            if not validate_url(inp):
                crashes += 1
                print("A crash occured in " + str(i+1))
                print("The input is: ", inp)
            inp = seed_input
    
    print("The total crash count is: ", crashes)

if __name__ == "__main__":
    noOfTests = int(input("Number of test cases? "))
    urlFuzzer(noOfTests)
# Out:
# Number of test cases?  1000
# A crash occured in 1
# The input is:  http://www.google.c"om/search?q=fuzzing
# A crash occured in 2
# The input is:  http:/+www.google.com/search?q=fuzzing
# A crash occured in 3
# The input is:  http://www.google.com/s\earch?q=fuzzing
# A crash occured in 4
# The input is:  http:/.www.google.com/search?q=fuzzing
# A crash occured in 8
# The input is:  http:/www.google.com/search?q=fuzzing
# A crash occured in 9
# The input is:  htYtp://www.google.com/search?q=fuzzing
# A crash occured in 13
# The input is:  Lhttp://www.google.com/search?q=fuzzing
# A crash occured in 14
# The input is:  http//www.google.com/search?q=fuzzing
# A crash occured in 15
# The input is:  http://www>google.com/search?q=fuzzing
# A crash occured in 19
# The input is:  http://www.goog,e.com/search?q=fuzzing
# A crash occured in 20
# The input is:  http://www.google.com/searchq=fuzzing
# A crash occured in 28
# The input is:  http//www.google.com/search?q=fuzzing
# A crash occured in 29
# The input is:  http://www.google.com/search7q=fuzzing
# A crash occured in 31
# The input is:  hptp://www.google.com/search?q=fuzzing
# A crash occured in 32
# The input is:  h,ttp://www.google.com/search?q=fuzzing
# A crash occured in 33
# The input is:  http:/C/www.google.com/search?q=fuzzing
# A crash occured in 35
# The input is:  httr://www.google.com/search?q=fuzzing
# A crash occured in 36
# The input is:  Vhttp://www.google.com/search?q=fuzzing
# A crash occured in 37
# The input is:  http://www.google.[com/search?q=fuzzing
# A crash occured in 39
# The input is:  htt`://www.google.com/search?q=fuzzing
# A crash occured in 40
# The input is:  http://www*google.com/search?q=fuzzing
# A crash occured in 42
# The input is:  http://www.google.com/s;earch?q=fuzzing
# A crash occured in 45
# The input is:  http:/www.google.com/search?q=fuzzing
# A crash occured in 47
# The input is:  http://www.google.com/search?q=fuz{ing
# A crash occured in 51
# The input is:  http:#//www.google.com/search?q=fuzzing
# A crash occured in 53
# The input is:  http//www.google.com/search?q=fuzzing
# A crash occured in 56
# The input is:  http://www.google.com/search?q=fuzz(ing
# A crash occured in 63
# The input is:  http://www.google.com/search?q=fuzzing>
# A crash occured in 67
# The input is:  http://www.google.com%/search?q=fuzzing
# A crash occured in 69
# The input is:  http:/www.google.com/search?q=fuzzing
# A crash occured in 72
# The input is:  htt8p://www.google.com/search?q=fuzzing
# A crash occured in 73
# The input is:  http://www.google.com/search?q=f:uzzing
# A crash occured in 76
# The input is:  ittp://www.google.com/search?q=fuzzing
# A crash occured in 77
# The input is:  http://www*google.com/search?q=fuzzing
# A crash occured in 78
# The input is:  http:o/www.google.com/search?q=fuzzing
# A crash occured in 82
# The input is:  http://www.google.com/search=q=fuzzing
# A crash occured in 83
# The input is:  http://www.google.com/search?q=fuz:ing
# A crash occured in 85
# The input is:  http://www.google.com/search??q=fuzzing
# A crash occured in 89
# The input is:  http:K//www.google.com/search?q=fuzzing
# A crash occured in 91
# The input is:  http;//www.google.com/search?q=fuzzing
# A crash occured in 92
# The input is:  http://www.google.com/search?q=f^uzzing
# A crash occured in 96
# The input is:  http://www.google.com/search;q=fuzzing
# A crash occured in 97
# The input is:  http:#//www.google.com/search?q=fuzzing
# A crash occured in 102
# The input is:  http:/www.google.com/search?q=fuzzing
# A crash occured in 103
# The input is:  http://www.google.com/search?q=fuzzin$g
# A crash occured in 106
# The input is:  http://www.google.cm/search?q=fuzzing
# A crash occured in 113
# The input is:  http://www.google.com/search?q=fuz{zing
# A crash occured in 117
# The input is:  htt(p://www.google.com/search?q=fuzzing
# A crash occured in 128
# The input is:  http://www,google.com/search?q=fuzzing
# A crash occured in 130
# The input is:  http:/+www.google.com/search?q=fuzzing
# A crash occured in 132
# The input is:  http://www.google.com/search?q=fuzzi,ng
# A crash occured in 134
# The input is:  ttp://www.google.com/search?q=fuzzing
# A crash occured in 137
# The input is:  http>//www.google.com/search?q=fuzzing
# A crash occured in 139
# The input is:  http:/www.google.com/search?q=fuzzing
# A crash occured in 140
# The input is:  http://www.google.com/searchq=fuzzing
# A crash occured in 145
# The input is:  http:J//www.google.com/search?q=fuzzing
# A crash occured in 149
# The input is:  http:$//www.google.com/search?q=fuzzing
# A crash occured in 150
# The input is:  http://www.google.com/search?q=f}zzing
# A crash occured in 151
# The input is:  ht%tp://www.google.com/search?q=fuzzing
# A crash occured in 153
# The input is:  http:/t/www.google.com/search?q=fuzzing
# A crash occured in 154
# The input is:  http*//www.google.com/search?q=fuzzing
# A crash occured in 156
# The input is:  `ttp://www.google.com/search?q=fuzzing
# A crash occured in 159
# The input is:  http://www.google.com/search?q=f'uzzing
# A crash occured in 160
# The input is:  http://www.google.com/searchq=fuzzing
# A crash occured in 166
# The input is:  http:/www.google.com/search?q=fuzzing
# A crash occured in 170
# The input is:  http://www.'oogle.com/search?q=fuzzing
# A crash occured in 171
# The input is:  hhttp://www.google.com/search?q=fuzzing
# A crash occured in 174
# The input is:  http://www.google.com/searchq=fuzzing
# A crash occured in 176
# The input is:  http://www.google.com/search?q=fuz|zing
# A crash occured in 177
# The input is:  http:/www.google.com/search?q=fuzzing
# A crash occured in 179
# The input is:  ttp://www.google.com/search?q=fuzzing
# A crash occured in 186
# The input is:  http://www.google.com?/search?q=fuzzing
# A crash occured in 187
# The input is:  http://www.google.com/search?q=fuz%zing
# A crash occured in 188
# The input is:  http://ww.google.com/search?q=fuzzing
# A crash occured in 191
# The input is:  ttp://www.google.com/search?q=fuzzing
# A crash occured in 194
# The input is:  htttp://www.google.com/search?q=fuzzing
# A crash occured in 201
# The input is:  http://www.google.com/se|arch?q=fuzzing
# A crash occured in 204
# The input is:  http;//www.google.com/search?q=fuzzing
# A crash occured in 209
# The input is:  http://www.google.com/search?q=fuz:zing
# A crash occured in 211
# The input is:  http:1//www.google.com/search?q=fuzzing
# A crash occured in 212
# The input is:  http://www.google.com/searchq=fuzzing
# A crash occured in 213
# The input is:  http//www.google.com/search?q=fuzzing
# A crash occured in 214
# The input is:  hutp://www.google.com/search?q=fuzzing
# A crash occured in 216
# The input is:  htpp://www.google.com/search?q=fuzzing
# A crash occured in 217
# The input is:  http://ww.google.com/search?q=fuzzing
# A crash occured in 220
# The input is:  http//www.google.com/search?q=fuzzing
# A crash occured in 222
# The input is:  httpz//www.google.com/search?q=fuzzing
# A crash occured in 223
# The input is:  >http://www.google.com/search?q=fuzzing
# A crash occured in 227
# The input is:  http://www.google.com/se>arch?q=fuzzing
# A crash occured in 228
# The input is:  ttp://www.google.com/search?q=fuzzing
# A crash occured in 229
# The input is:  http:H//www.google.com/search?q=fuzzing
# A crash occured in 230
# The input is:  http ://www.google.com/search?q=fuzzing
# A crash occured in 233
# The input is:  ht4p://www.google.com/search?q=fuzzing
# A crash occured in 234
# The input is:  http:://www.google.com/search?q=fuzzing
# A crash occured in 235
# The input is:  http://www.google:.com/search?q=fuzzing
# A crash occured in 238
# The input is:  http://www.google.^com/search?q=fuzzing
# A crash occured in 239
# The input is:  http://www.google.com/search?q=fuz@zing
# A crash occured in 241
# The input is:  http://www.google.com/search?q=%fuzzing
# A crash occured in 246
# The input is:  http://www.google.com/search?q=fu~zing
# A crash occured in 247
# The input is:  htp://www.google.com/search?q=fuzzing
# A crash occured in 251
# The input is:  http://www.g&oogle.com/search?q=fuzzing
# A crash occured in 255
# The input is:  http://www.'oogle.com/search?q=fuzzing
# A crash occured in 258
# The input is:  htp://www.google.com/search?q=fuzzing
# A crash occured in 263
# The input is:  htbtp://www.google.com/search?q=fuzzing
# A crash occured in 264
# The input is:  http:/m/www.google.com/search?q=fuzzing
# A crash occured in 265
# The input is:  htp://www.google.com/search?q=fuzzing
# A crash occured in 267
# The input is:  htt://www.google.com/search?q=fuzzing
# A crash occured in 272
# The input is:  http://www>google.com/search?q=fuzzing
# A crash occured in 293
# The input is:  http://www.google.com/search?q=fuzzi~g
# A crash occured in 295
# The input is:  http://www.google.com?search?q=fuzzing
# A crash occured in 297
# The input is:  http://www.google.com/{earch?q=fuzzing
# A crash occured in 301
# The input is:  http://www.google:.com/search?q=fuzzing
# A crash occured in 308
# The input is:  Http://www.google.com/search?q=fuzzing
# A crash occured in 309
# The input is:  htt'p://www.google.com/search?q=fuzzing
# A crash occured in 310
# The input is:  http://www.google.com/sear,ch?q=fuzzing
# A crash occured in 320
# The input is:  httt://www.google.com/search?q=fuzzing
# A crash occured in 322
# The input is:  http://www.google.com/search?q=fuzzi.g
# A crash occured in 324
# The input is:  http:/owww.google.com/search?q=fuzzing
# A crash occured in 325
# The input is:  htt"p://www.google.com/search?q=fuzzing
# A crash occured in 327
# The input is:  http:./www.google.com/search?q=fuzzing
# A crash occured in 328
# The input is:  http://www.google.com/sear%ch?q=fuzzing
# A crash occured in 329
# The input is:  http://www.google.com/search?q=fuzzing!
# A crash occured in 330
# The input is:  http://www.google.com/search?q=fuzzi.g
# A crash occured in 333
# The input is:  _http://www.google.com/search?q=fuzzing
# A crash occured in 335
# The input is:  http://www.google.com/search?q=fuz~ing
# A crash occured in 337
# The input is:  ht}tp://www.google.com/search?q=fuzzing
# A crash occured in 339
# The input is:  http://www.google.com/se`arch?q=fuzzing
# A crash occured in 342
# The input is:  http://www.g,oogle.com/search?q=fuzzing
# A crash occured in 350
# The input is:  htt://www.google.com/search?q=fuzzing
# A crash occured in 354
# The input is:  http://www.google.com/searc+h?q=fuzzing
# A crash occured in 355
# The input is:  http://www.google>com/search?q=fuzzing
# A crash occured in 359
# The input is:  http://www.google.com/searchq=fuzzing
# A crash occured in 360
# The input is:  http://www.}google.com/search?q=fuzzing
# A crash occured in 362
# The input is:  http://www.google.co:m/search?q=fuzzing
# A crash occured in 364
# The input is:  ht2tp://www.google.com/search?q=fuzzing
# A crash occured in 365
# The input is:  hvtp://www.google.com/search?q=fuzzing
# A crash occured in 366
# The input is:  http://www.google.#om/search?q=fuzzing
# A crash occured in 367
# The input is:  Ghttp://www.google.com/search?q=fuzzing
# A crash occured in 376
# The input is:  hutp://www.google.com/search?q=fuzzing
# A crash occured in 377
# The input is:  http:/_/www.google.com/search?q=fuzzing
# A crash occured in 378
# The input is:  http:/www.google.com/search?q=fuzzing
# A crash occured in 381
# The input is:  http3://www.google.com/search?q=fuzzing
# A crash occured in 383
# The input is:  http:/www.google.com/search?q=fuzzing
# A crash occured in 388
# The input is:  "http://www.google.com/search?q=fuzzing
# A crash occured in 389
# The input is:  http://www.google.com/{earch?q=fuzzing
# A crash occured in 390
# The input is:  http://www.google.com+search?q=fuzzing
# A crash occured in 391
# The input is:  http://ww|w.google.com/search?q=fuzzing
# A crash occured in 396
# The input is:  http://www.google.com/search?q=fuzzi~g
# A crash occured in 397
# The input is:  htt://www.google.com/search?q=fuzzing
# A crash occured in 399
# The input is:  http://www.google.:com/search?q=fuzzing
# A crash occured in 407
# The input is:  http:/www.google.com/search?q=fuzzing
# A crash occured in 410
# The input is:  http;//www.google.com/search?q=fuzzing
# A crash occured in 413
# The input is:  http:/'www.google.com/search?q=fuzzing
# A crash occured in 420
# The input is:  http://www.google.com/search?q=)fuzzing
# A crash occured in 421
# The input is:  http://www.google.com/se`rch?q=fuzzing
# A crash occured in 422
# The input is:  httq://www.google.com/search?q=fuzzing
# A crash occured in 425
# The input is:  http://www.google.com/searchq=fuzzing
# A crash occured in 429
# The input is:  httq://www.google.com/search?q=fuzzing
# A crash occured in 432
# The input is:  httpz//www.google.com/search?q=fuzzing
# A crash occured in 437
# The input is:  ttp://www.google.com/search?q=fuzzing
# A crash occured in 442
# The input is:  ht-tp://www.google.com/search?q=fuzzing
# A crash occured in 444
# The input is:  http://www.google.com/search?q=fu~zing
# A crash occured in 453
# The input is:  http://www.google.com/searchq=fuzzing
# A crash occured in 454
# The input is:  http:/www.google.com/search?q=fuzzing
# A crash occured in 458
# The input is:  http://www.g!oogle.com/search?q=fuzzing
# A crash occured in 459
# The input is:  http://www.google.com/search?q=fuzz/ing
# A crash occured in 462
# The input is:  htpp://www.google.com/search?q=fuzzing
# A crash occured in 463
# The input is:  httpw://www.google.com/search?q=fuzzing
# A crash occured in 464
# The input is:  http://www.google.#om/search?q=fuzzing
# A crash occured in 465
# The input is:  jttp://www.google.com/search?q=fuzzing
# A crash occured in 468
# The input is:  h;ttp://www.google.com/search?q=fuzzing
# A crash occured in 473
# The input is:  http://www.googl>e.com/search?q=fuzzing
# A crash occured in 474
# The input is:  http://www.`google.com/search?q=fuzzing
# A crash occured in 476
# The input is:  http:'/www.google.com/search?q=fuzzing
# A crash occured in 477
# The input is:  http:-/www.google.com/search?q=fuzzing
# A crash occured in 478
# The input is:  httpa://www.google.com/search?q=fuzzing
# A crash occured in 480
# The input is:  http://www.google.com/searchq=fuzzing
# A crash occured in 481
# The input is:  http://www.google.com/>search?q=fuzzing
# A crash occured in 483
# The input is:  http://www.~google.com/search?q=fuzzing
# A crash occured in 484
# The input is:  http//www.google.com/search?q=fuzzing
# A crash occured in 485
# The input is:  htt0://www.google.com/search?q=fuzzing
# A crash occured in 492
# The input is:  http://www.google.com/searc`?q=fuzzing
# A crash occured in 494
# The input is:  http://www.google.com/search?qfuzzing
# A crash occured in 498
# The input is:  http://"www.google.com/search?q=fuzzing
# A crash occured in 499
# The input is:  http://www.google.com/search?q=fuzz ing
# A crash occured in 500
# The input is:  http://www.google.c:om/search?q=fuzzing
# A crash occured in 504
# The input is:  hTtp://www.google.com/search?q=fuzzing
# A crash occured in 506
# The input is:  http://www&google.com/search?q=fuzzing
# A crash occured in 512
# The input is:  http:/www.google.com/search?q=fuzzing
# A crash occured in 513
# The input is:  http//www.google.com/search?q=fuzzing
# A crash occured in 516
# The input is:  h4tp://www.google.com/search?q=fuzzing
# A crash occured in 520
# The input is:  http//www.google.com/search?q=fuzzing
# A crash occured in 527
# The input is:  http;//www.google.com/search?q=fuzzing
# A crash occured in 530
# The input is:  http:+/www.google.com/search?q=fuzzing
# A crash occured in 533
# The input is:  http:/]/www.google.com/search?q=fuzzing
# A crash occured in 536
# The input is:  http://www.google.com/sear:ch?q=fuzzing
# A crash occured in 543
# The input is:  htatp://www.google.com/search?q=fuzzing
# A crash occured in 545
# The input is:  httq://www.google.com/search?q=fuzzing
# A crash occured in 546
# The input is:  http://www.google.com/search?q=fu|zzing
# A crash occured in 550
# The input is:  http://www.google.com/!search?q=fuzzing
# A crash occured in 551
# The input is:  http//www.google.com/search?q=fuzzing
# A crash occured in 553
# The input is:  http:~//www.google.com/search?q=fuzzing
# A crash occured in 554
# The input is:  http//www.google.com/search?q=fuzzing
# A crash occured in 555
# The input is:  ttp://www.google.com/search?q=fuzzing
# A crash occured in 559
# The input is:  http:/www.google.com/search?q=fuzzing
# A crash occured in 560
# The input is:  hBttp://www.google.com/search?q=fuzzing
# A crash occured in 562
# The input is:  http://www.google.com/searchq=fuzzing
# A crash occured in 563
# The input is:  http://www.google.com/search=?q=fuzzing
# A crash occured in 564
# The input is:  ht~tp://www.google.com/search?q=fuzzing
# A crash occured in 567
# The input is:  ttp://www.google.com/search?q=fuzzing
# A crash occured in 568
# The input is:  http//www.google.com/search?q=fuzzing
# A crash occured in 571
# The input is:  http://www.google.com/search7q=fuzzing
# A crash occured in 572
# The input is:  htFtp://www.google.com/search?q=fuzzing
# A crash occured in 577
# The input is:  http://www.google.com/search?q=%fuzzing
# A crash occured in 581
# The input is:  (ttp://www.google.com/search?q=fuzzing
# A crash occured in 583
# The input is:  http*//www.google.com/search?q=fuzzing
# A crash occured in 584
# The input is:  http://www.google.com/se!rch?q=fuzzing
# A crash occured in 587
# The input is:  http>//www.google.com/search?q=fuzzing
# A crash occured in 588
# The input is:  http:/www.google.com/search?q=fuzzing
# A crash occured in 592
# The input is:  http://`www.google.com/search?q=fuzzing
# A crash occured in 596
# The input is:  http://www.google.com/,search?q=fuzzing
# A crash occured in 603
# The input is:  h|tp://www.google.com/search?q=fuzzing
# A crash occured in 606
# The input is:  http://www.google.com/search>q=fuzzing
# A crash occured in 608
# The input is:  http:/www.google.com/search?q=fuzzing
# A crash occured in 616
# The input is:  http:/www.google.com/search?q=fuzzing
# A crash occured in 621
# The input is:  ttp://www.google.com/search?q=fuzzing
# A crash occured in 625
# The input is:  hnttp://www.google.com/search?q=fuzzing
# A crash occured in 626
# The input is:  http://www.googlecom/search?q=fuzzing
# A crash occured in 627
# The input is:  lttp://www.google.com/search?q=fuzzing
# A crash occured in 630
# The input is:  h4tp://www.google.com/search?q=fuzzing
# A crash occured in 639
# The input is:  http://www.google.com/searc{h?q=fuzzing
# A crash occured in 640
# The input is:  http:/-/www.google.com/search?q=fuzzing
# A crash occured in 641
# The input is:  http://www.google.com/searchq=fuzzing
# A crash occured in 645
# The input is:  ttp://www.google.com/search?q=fuzzing
# A crash occured in 655
# The input is:  h2ttp://www.google.com/search?q=fuzzing
# A crash occured in 659
# The input is:  http://www.google.com+search?q=fuzzing
# A crash occured in 662
# The input is:  http://www.google.com/searc%h?q=fuzzing
# A crash occured in 663
# The input is:  http:/'/www.google.com/search?q=fuzzing
# A crash occured in 664
# The input is:  `ttp://www.google.com/search?q=fuzzing
# A crash occured in 669
# The input is:  `ttp://www.google.com/search?q=fuzzing
# A crash occured in 671
# The input is:  http://www.google.#om/search?q=fuzzing
# A crash occured in 673
# The input is:  http:/@/www.google.com/search?q=fuzzing
# A crash occured in 678
# The input is:  http://www.google.com/searchq=fuzzing
# A crash occured in 679
# The input is:  httpK://www.google.com/search?q=fuzzing
# A crash occured in 680
# The input is:  http:/7/www.google.com/search?q=fuzzing
# A crash occured in 682
# The input is:  http://www.goog~le.com/search?q=fuzzing
# A crash occured in 683
# The input is:  http://www:.google.com/search?q=fuzzing
# A crash occured in 684
# The input is:  http:/www.google.com/search?q=fuzzing
# A crash occured in 690
# The input is:  httq://www.google.com/search?q=fuzzing
# A crash occured in 693
# The input is:  htp://www.google.com/search?q=fuzzing
# A crash occured in 694
# The input is:  http://www.google.com/s:earch?q=fuzzing
# A crash occured in 697
# The input is:  http://www.google.com/searchq=fuzzing
# A crash occured in 698
# The input is:  http://www.google.com/searchq=fuzzing
# A crash occured in 700
# The input is:  http>//www.google.com/search?q=fuzzing
# A crash occured in 702
# The input is:  http://www.googlecom/search?q=fuzzing
# A crash occured in 703
# The input is:  http://www.google.com/sear{ch?q=fuzzing
# A crash occured in 706
# The input is:  http://www.google.com/searchq=fuzzing
# A crash occured in 713
# The input is:  http://ww$w.google.com/search?q=fuzzing
# A crash occured in 714
# The input is:  http\://www.google.com/search?q=fuzzing
# A crash occured in 716
# The input is:  http:/a/www.google.com/search?q=fuzzing
# A crash occured in 720
# The input is:  http://www.google.com/search?q=fuzzin`g
# A crash occured in 722
# The input is:  http://www.google?.com/search?q=fuzzing
# A crash occured in 723
# The input is:  ttp://www.google.com/search?q=fuzzing
# A crash occured in 732
# The input is:  ttp://www.google.com/search?q=fuzzing
# A crash occured in 733
# The input is:  http://www.'oogle.com/search?q=fuzzing
# A crash occured in 735
# The input is:  http:/www.google.com/search?q=fuzzing
# A crash occured in 738
# The input is:  htdp://www.google.com/search?q=fuzzing
# A crash occured in 739
# The input is:  http://www.gogle.com/search?q=fuzzing
# A crash occured in 742
# The input is:  http://www.google.com/searc`?q=fuzzing
# A crash occured in 745
# The input is:  http:|//www.google.com/search?q=fuzzing
# A crash occured in 746
# The input is:  http://www.googl%.com/search?q=fuzzing
# A crash occured in 749
# The input is:  ttp://www.google.com/search?q=fuzzing
# A crash occured in 751
# The input is:  http:/u/www.google.com/search?q=fuzzing
# A crash occured in 754
# The input is:  http://ww.google.com/search?q=fuzzing
# A crash occured in 761
# The input is:  chttp://www.google.com/search?q=fuzzing
# A crash occured in 766
# The input is:  http://www.google.com/search?q=fuzzin@g
# A crash occured in 767
# The input is:  http://www.google.com/search?q=fu~zing
# A crash occured in 769
# The input is:  http//www.google.com/search?q=fuzzing
# A crash occured in 771
# The input is:  httpB://www.google.com/search?q=fuzzing
# A crash occured in 773
# The input is:  http://www.google.com/searchq=fuzzing
# A crash occured in 774
# The input is:  httCp://www.google.com/search?q=fuzzing
# A crash occured in 778
# The input is:  http://www.g?oogle.com/search?q=fuzzing
# A crash occured in 787
# The input is:  http:// www.google.com/search?q=fuzzing
# A crash occured in 794
# The input is:  http://www>google.com/search?q=fuzzing
# A crash occured in 796
# The input is:  http://www.google.com/se:arch?q=fuzzing
# A crash occured in 800
# The input is:  http://www.google.com/search?{q=fuzzing
# A crash occured in 801
# The input is:  http://www.google.com@/search?q=fuzzing
# A crash occured in 803
# The input is:  http://www.google.com/search?q=fuzz*ing
# A crash occured in 810
# The input is:  httP://www.google.com/search?q=fuzzing
# A crash occured in 812
# The input is:  http://www.goo!gle.com/search?q=fuzzing
# A crash occured in 815
# The input is:  http://www.google.com/sea(rch?q=fuzzing
# A crash occured in 824
# The input is:  http://www.google.com/search/q=fuzzing
# A crash occured in 836
# The input is:  http://www.google.com/search?q=fuzz}ing
# A crash occured in 837
# The input is:  http://www.google.com/search>q=fuzzing
# A crash occured in 841
# The input is:  http://www.google.com/search?q=fuzzi ng
# A crash occured in 846
# The input is:  http:/www.google.com/search?q=fuzzing
# A crash occured in 850
# The input is:  http:+/www.google.com/search?q=fuzzing
# A crash occured in 856
# The input is:  http//www.google.com/search?q=fuzzing
# A crash occured in 859
# The input is:  http:/I/www.google.com/search?q=fuzzing
# A crash occured in 864
# The input is:  h4tp://www.google.com/search?q=fuzzing
# A crash occured in 867
# The input is:  http:/T/www.google.com/search?q=fuzzing
# A crash occured in 870
# The input is:  http://www.google.co]m/search?q=fuzzing
# A crash occured in 872
# The input is:  http//www.google.com/search?q=fuzzing
# A crash occured in 875
# The input is:  http://www.;google.com/search?q=fuzzing
# A crash occured in 879
# The input is:  http:/www.google.com/search?q=fuzzing
# A crash occured in 881
# The input is:  http://www.google.com/search?q=fu{zing
# A crash occured in 884
# The input is:  h|tp://www.google.com/search?q=fuzzing
# A crash occured in 885
# The input is:  Http://www.google.com/search?q=fuzzing
# A crash occured in 887
# The input is:  http://www.google.com/search?q=fuzzin'
# A crash occured in 892
# The input is:  htt://www.google.com/search?q=fuzzing
# A crash occured in 894
# The input is:  ht7tp://www.google.com/search?q=fuzzing
# A crash occured in 896
# The input is:  httip://www.google.com/search?q=fuzzing
# A crash occured in 907
# The input is:  htp://www.google.com/search?q=fuzzing
# A crash occured in 910
# The input is:  http://www.google.?com/search?q=fuzzing
# A crash occured in 911
# The input is:  http>//www.google.com/search?q=fuzzing
# A crash occured in 912
# The input is:  http://www.google.com/search?q}fuzzing
# A crash occured in 915
# The input is:  huttp://www.google.com/search?q=fuzzing
# A crash occured in 916
# The input is:  http://www.'oogle.com/search?q=fuzzing
# A crash occured in 918
# The input is:  htp://www.google.com/search?q=fuzzing
# A crash occured in 919
# The input is:  http//www.google.com/search?q=fuzzing
# A crash occured in 920
# The input is:  hCttp://www.google.com/search?q=fuzzing
# A crash occured in 921
# The input is:  http://www.google.com/!search?q=fuzzing
# A crash occured in 927
# The input is:  http:/S/www.google.com/search?q=fuzzing
# A crash occured in 933
# The input is:  http://www.go$ogle.com/search?q=fuzzing
# A crash occured in 935
# The input is:  http://www.google.c~om/search?q=fuzzing
# A crash occured in 938
# The input is:  htpp://www.google.com/search?q=fuzzing
# A crash occured in 940
# The input is:  hmttp://www.google.com/search?q=fuzzing
# A crash occured in 941
# The input is:  http://www.google.com/s,earch?q=fuzzing
# A crash occured in 943
# The input is:  htt://www.google.com/search?q=fuzzing
# A crash occured in 944
# The input is:  Mhttp://www.google.com/search?q=fuzzing
# A crash occured in 946
# The input is:  http://www.google.com/search?q=fuzzi~g
# A crash occured in 949
# The input is:  http:/owww.google.com/search?q=fuzzing
# A crash occured in 950
# The input is:  httpO://www.google.com/search?q=fuzzing
# A crash occured in 955
# The input is:  http*//www.google.com/search?q=fuzzing
# A crash occured in 960
# The input is:  htp://www.google.com/search?q=fuzzing
# A crash occured in 965
# The input is:  ht|p://www.google.com/search?q=fuzzing
# A crash occured in 966
# The input is:  jttp://www.google.com/search?q=fuzzing
# A crash occured in 968
# The input is:  httpK://www.google.com/search?q=fuzzing
# A crash occured in 970
# The input is:  http:/www.google.com/search?q=fuzzing
# A crash occured in 971
# The input is:  http://www.google.com/search?q=fuzzin'
# A crash occured in 975
# The input is:  http://www.google.com/search?q=fuzz~ing
# A crash occured in 978
# The input is:  http://www.^google.com/search?q=fuzzing
# A crash occured in 981
# The input is:  http//www.google.com/search?q=fuzzing
# A crash occured in 983
# The input is:  http://www&google.com/search?q=fuzzing
# A crash occured in 989
# The input is:  htt://www.google.com/search?q=fuzzing
# A crash occured in 994
# The input is:  httVp://www.google.com/search?q=fuzzing
# A crash occured in 997
# The input is:  http://wwwgoogle.com/search?q=fuzzing
# A crash occured in 998
# The input is:  http://www.goog,e.com/search?q=fuzzing
# The total crash count is:  348

# %%
import random
import time
import re

def delete_random_character(s: str) -> str:
    
    if s == "":
        return s

    pos = random.randint(0, len(s) - 1)
    return s[:pos] + s[pos + 1:]

def insert_random_character(s: str) -> str:
    
    pos = random.randint(0, len(s))
    random_character = chr(random.randrange(32, 127))
    return s[:pos] + random_character + s[pos:]

def flip_random_character(s):
    
    if s == "":
        return s

    pos = random.randint(0, len(s) - 1)
    c = s[pos]
    bit = 1 << random.randint(0, 6)
    new_c = chr(ord(c) ^ bit)
    return s[:pos] + new_c + s[pos + 1:]

def mutate(s: str) -> str:
    
    mutators = [
        delete_random_character,
        insert_random_character,
        flip_random_character
    ]
    mutator = random.choice(mutators)
    
    return mutator(s)

def validate_url(url):
    pattern = r'^(http|https|ftp)://([\w.-]+)(/[\w./]*)?(\?[\w=&-]+)?(#\w+)?$'
    if re.match(pattern, url):
        return True
    else:
        return False

def urlFuzzer(noOfTests):
    
    seed_input = "http://www.google.com/search?q=fuzzing"
    # mutations = 20
    inp = seed_input
    crashes = 0

    for i in range(noOfTests):
        if i <= noOfTests:
            inp = mutate(inp)
            # print("Test case ", (i+1), ": ", repr(inp))
            
            if not validate_url(inp):
                crashes += 1
                # print("A crash occured in " + str(i+1))
                print("The crash input is: ", inp)
            inp = seed_input
    
    print("The total crash count is: ", crashes)

if __name__ == "__main__":
    noOfTests = int(input("Number of test cases? "))
    urlFuzzer(noOfTests)
# Out:
# Number of test cases?  10000
# The crash input is:  http://ww`w.google.com/search?q=fuzzing
# The crash input is:  http://www".google.com/search?q=fuzzing
# The crash input is:  http://www.goo\gle.com/search?q=fuzzing
# The crash input is:  ittp://www.google.com/search?q=fuzzing
# The crash input is:  http*//www.google.com/search?q=fuzzing
# The crash input is:  http://www.google.com/search?q=fuzzing$
# The crash input is:  http://www.google.c[om/search?q=fuzzing
# The crash input is:  htp://www.google.com/search?q=fuzzing
# The crash input is:  htt://www.google.com/search?q=fuzzing
# The crash input is:  http://www.google.com/search?q=|fuzzing
# The crash input is:  hutp://www.google.com/search?q=fuzzing
# The crash input is:  hdtp://www.google.com/search?q=fuzzing
# The crash input is:  http://www.google.com/:search?q=fuzzing
# The crash input is:  http://www.googlecom/search?q=fuzzing
# The crash input is:  htt://www.google.com/search?q=fuzzing
# The crash input is:  http://www.google.com/{earch?q=fuzzing
# The crash input is:  http://www.google.com/search?q=fu>zzing
# The crash input is:  http://www.google.co)m/search?q=fuzzing
# The crash input is:  http://www.go<ogle.com/search?q=fuzzing
# The crash input is:  http:/n/www.google.com/search?q=fuzzing
# The crash input is:  http://www.google*com/search?q=fuzzing
# The crash input is:  h4tp://www.google.com/search?q=fuzzing
# The crash input is:  http`://www.google.com/search?q=fuzzing
# The crash input is:  http://www.google.com/searchq=fuzzing
# The crash input is:  htt]p://www.google.com/search?q=fuzzing
# The crash input is:  http://www.goo'le.com/search?q=fuzzing
# The crash input is:  htp://www.google.com/search?q=fuzzing
# The crash input is:  http:/M/www.google.com/search?q=fuzzing
# The crash input is:  htt://www.google.com/search?q=fuzzing
# The crash input is:  http://www.google.com/searchq=fuzzing
# The crash input is:  jttp://www.google.com/search?q=fuzzing
# The crash input is:  http//www.google.com/search?q=fuzzing
# The crash input is:  http:/k/www.google.com/search?q=fuzzing
# The crash input is:  http://www.google.com/search?q=fuzzin|g
# The crash input is:  http:/www.google.com/search?q=fuzzing
# The crash input is:  http://www.google.com/search7q=fuzzing
# The crash input is:  http://www.google.com#/search?q=fuzzing
# The crash input is:  http:/www.google.com/search?q=fuzzing
# The crash input is:  http://www.google.com/s%arch?q=fuzzing
# The crash input is:  http:/?www.google.com/search?q=fuzzing
# The crash input is:  http://www.google.com/search?q=fuz$zing
# The crash input is:  httx://www.google.com/search?q=fuzzing
# The crash input is:  http://www.>google.com/search?q=fuzzing
# The crash input is:  http://www.google.c,om/search?q=fuzzing
# The crash input is:  htp://www.google.com/search?q=fuzzing
# The crash input is:  http://www.google.com/search?q=fu!zzing
# The crash input is:  hattp://www.google.com/search?q=fuzzing
# The crash input is:  http//www.google.com/search?q=fuzzing
# The crash input is:  htt`://www.google.com/search?q=fuzzing
# The crash input is:  http://www.google'.com/search?q=fuzzing
# The crash input is:  ttp://www.google.com/search?q=fuzzing
# The crash input is:  http://www.]google.com/search?q=fuzzing
# The crash input is:  (ttp://www.google.com/search?q=fuzzing
# The crash input is:  httpl://www.google.com/search?q=fuzzing
# The crash input is:  httr://www.google.com/search?q=fuzzing
# The crash input is:  http://<www.google.com/search?q=fuzzing
# The crash input is:  http:/www.google.com/search?q=fuzzing
# The crash input is:  http://www.goo gle.com/search?q=fuzzing
# The crash input is:  http:/www.google.com/search?q=fuzzing
# The crash input is:  htp://www.google.com/search?q=fuzzing
# The crash input is:  http://www.goo gle.com/search?q=fuzzing
# The crash input is:  http://www.google.com/search?q=fuz{ing
# The crash input is:  htp://www.google.com/search?q=fuzzing
# The crash input is:  http://www.'google.com/search?q=fuzzing
# The crash input is:  http://www.google.com/search?|q=fuzzing
# The crash input is:  http:/-www.google.com/search?q=fuzzing
# The crash input is:  http:%//www.google.com/search?q=fuzzing
# The crash input is:  http://www.google,com/search?q=fuzzing
# The crash input is:  http:/www.google.com/search?q=fuzzing
# The crash input is:  http://www.google.com/search?q=fuzz?ing
# The crash input is:  http://www.google.com/searchq=fuzzing
# The crash input is:  http://www.g"oogle.com/search?q=fuzzing
# The crash input is:  http://www.google.com/search?q=fuz~ing
# The crash input is:  http:+/www.google.com/search?q=fuzzing
# The crash input is:  http://www.google.c;om/search?q=fuzzing
# The crash input is:  httq://www.google.com/search?q=fuzzing
# The crash input is:  hRttp://www.google.com/search?q=fuzzing
# The crash input is:  http://www.google.com/search7q=fuzzing
# The crash input is:  http:/owww.google.com/search?q=fuzzing
# The crash input is:  htt+p://www.google.com/search?q=fuzzing
# The crash input is:  htt://www.google.com/search?q=fuzzing
# The crash input is:  http://www.google.com/search?q?fuzzing
# The crash input is:  http://www.google.com/search?q=fuzzi)ng
# The crash input is:  http://www.google.com/searchq=fuzzing
# The crash input is:  ttp://www.google.com/search?q=fuzzing
# The crash input is:  http:./www.google.com/search?q=fuzzing
# The crash input is:  http://www.googlecom/search?q=fuzzing
# The crash input is:  http//www.google.com/search?q=fuzzing
# The crash input is:  http//www.google.com/search?q=fuzzing
# The crash input is:  Yhttp://www.google.com/search?q=fuzzing
# The crash input is:  http://www.google.com/search?q=fuzz$ing
# The crash input is:  http://www.google.com/search?q=fuz:ing
# The crash input is:  htpp://www.google.com/search?q=fuzzing
# The crash input is:  http://www.google.com/search?q=f:uzzing
# The crash input is:  ttp://www.google.com/search?q=fuzzing
# The crash input is:  http:x//www.google.com/search?q=fuzzing
# The crash input is:  http:/www.google.com/search?q=fuzzing
# The crash input is:  http://www.google.com/search?q=fuzzing?
# The crash input is:  http//www.google.com/search?q=fuzzing
# The crash input is:  http8//www.google.com/search?q=fuzzing
# The crash input is:  http://www.google.com/search?@q=fuzzing
# The crash input is:  http:/www.google.com/search?q=fuzzing
# The crash input is:  http://;www.google.com/search?q=fuzzing
# The crash input is:  ht]tp://www.google.com/search?q=fuzzing
# The crash input is:  http://$www.google.com/search?q=fuzzing
# The crash input is:  http://www.google.com/search?q^=fuzzing
# The crash input is:  ttp://www.google.com/search?q=fuzzing
# The crash input is:  http:/g/www.google.com/search?q=fuzzing
# The crash input is:  http:/www.google.com/search?q=fuzzing
# The crash input is:  http://www.google.com/searchq=fuzzing
# The crash input is:  http://www.goog}le.com/search?q=fuzzing
# The crash input is:  httq://www.google.com/search?q=fuzzing
# The crash input is:  http://www.google.com/sear#h?q=fuzzing
# The crash input is:  http://www.google.com/s=earch?q=fuzzing
# The crash input is:  http:y//www.google.com/search?q=fuzzing
# The crash input is:  `ttp://www.google.com/search?q=fuzzing
# The crash input is:  htt://www.google.com/search?q=fuzzing
# The crash input is:  http://www.goog$le.com/search?q=fuzzing
# The crash input is:  hTtp://www.google.com/search?q=fuzzing
# The crash input is:  http://www.google.com/search?^q=fuzzing
# The crash input is:  `ttp://www.google.com/search?q=fuzzing
# The crash input is:  http//www.google.com/search?q=fuzzing
# The crash input is:  http:/www.google.com/search?q=fuzzing
# The crash input is:  http:./www.google.com/search?q=fuzzing
# The crash input is:  htp://www.google.com/search?q=fuzzing
# The crash input is:  http:/www.google.com/search?q=fuzzing
# The crash input is:  http://www.google.com/s earch?q=fuzzing
# The crash input is:  http://www.google.com/search?q=fuz:ing
# The crash input is:  http://www.google.com/search?q=fuzzing]
# The crash input is:  ttp://www.google.com/search?q=fuzzing
# The crash input is:  http:/www.google.com/search?q=fuzzing
# The crash input is:  htp://www.google.com/search?q=fuzzing
# The crash input is:  htp://www.google.com/search?q=fuzzing
# The crash input is:  http://www.google.com/searc(?q=fuzzing
# The crash input is:  http//www.google.com/search?q=fuzzing
# The crash input is:  ttp://www.google.com/search?q=fuzzing
# The crash input is:  http://www.google.cm/search?q=fuzzing
# The crash input is:  http://www.google.com/search?q=fuzz,ing
# The crash input is:  http://www.google*com/search?q=fuzzing
# The crash input is:  http:'//www.google.com/search?q=fuzzing
# The crash input is:  htp://www.google.com/search?q=fuzzing
# The crash input is:  ihttp://www.google.com/search?q=fuzzing
# The crash input is:  ht{tp://www.google.com/search?q=fuzzing
# The crash input is:  http://www.google.(com/search?q=fuzzing
# The crash input is:  http://www.google.com/search*?q=fuzzing
# The crash input is:  http:k//www.google.com/search?q=fuzzing
# The crash input is:  http://www.google.com?search?q=fuzzing
# The crash input is:  http://www.google.com/se|arch?q=fuzzing
# The crash input is:  http://www.g;oogle.com/search?q=fuzzing
# The crash input is:  http:/www.google.com/search?q=fuzzing
# The crash input is:  http:?/www.google.com/search?q=fuzzing
# The crash input is:  h|tp://www.google.com/search?q=fuzzing
# The crash input is:  http://www.google.com/search?qfuzzing
# The crash input is:  http://www.'oogle.com/search?q=fuzzing
# The crash input is:  http:,//www.google.com/search?q=fuzzing
# The crash input is:  http://www.google.com/search#?q=fuzzing
# The crash input is:  http://www.g>oogle.com/search?q=fuzzing
# The crash input is:  http://www.google.com/sea,rch?q=fuzzing
# The crash input is:  htp://www.google.com/search?q=fuzzing
# The crash input is:  http:/www.google.com/search?q=fuzzing
# The crash input is:  htpp://www.google.com/search?q=fuzzing
# The crash input is:  http//www.google.com/search?q=fuzzing
# The crash input is:  http2//www.google.com/search?q=fuzzing
# The crash input is:  http://www.google.com/search?q=f"uzzing
# The crash input is:  http://www.google.com/search?q=fuzz)ng
# The crash input is:  htthp://www.google.com/search?q=fuzzing
# The crash input is:  http://www.goog=le.com/search?q=fuzzing
# The crash input is:  http:/www.google.com/search?q=fuzzing
# The crash input is:  http:/.www.google.com/search?q=fuzzing
# The crash input is:  httpd://www.google.com/search?q=fuzzing
# The crash input is:  htTp://www.google.com/search?q=fuzzing
# The crash input is:  http://www.google.com/search?q=fuz~ing
# The crash input is:  http:/F/www.google.com/search?q=fuzzing
# The crash input is:  %http://www.google.com/search?q=fuzzing
# The crash input is:  http://www.google.com/sea;rch?q=fuzzing
# The crash input is:  http:+/www.google.com/search?q=fuzzing
# The crash input is:  http2//www.google.com/search?q=fuzzing
# The crash input is:  ht4p://www.google.com/search?q=fuzzing
# The crash input is:  http://www.google.com/search?q=fuz+zing
# The crash input is:  http://www.goog;le.com/search?q=fuzzing
# The crash input is:  http://www.google.com/:search?q=fuzzing
# The crash input is:  http://www.google.com/sea#rch?q=fuzzing
# The crash input is:  http:/www.google.com/search?q=fuzzing
# The crash input is:  hattp://www.google.com/search?q=fuzzing
# The crash input is:  http:w//www.google.com/search?q=fuzzing
# The crash input is:  http://www.google.com/search?q=fuzzin[g
# The crash input is:  http:`//www.google.com/search?q=fuzzing
# The crash input is:  http[://www.google.com/search?q=fuzzing
# The crash input is:  http://www.google.com/search?q=(fuzzing
# The crash input is:  ht4p://www.google.com/search?q=fuzzing
# The crash input is:  http://www.#google.com/search?q=fuzzing
# The crash input is:  http>//www.google.com/search?q=fuzzing
# The crash input is:  http://www*google.com/search?q=fuzzing
# The crash input is:  htjtp://www.google.com/search?q=fuzzing
# The crash input is:  Http://www.google.com/search?q=fuzzing
# The crash input is:  http//www.google.com/search?q=fuzzing
# The crash input is:  http://www.google.com/searchq=fuzzing
# The crash input is:  http:/www.google.com/search?q=fuzzing
# The crash input is:  http://www.googl=e.com/search?q=fuzzing
# The crash input is:  http://www.google.,com/search?q=fuzzing
# The crash input is:  http://www.google.co m/search?q=fuzzing
# The crash input is:  http:/2/www.google.com/search?q=fuzzing
# The crash input is:  http:/www.google.com/search?q=fuzzing
# The crash input is:  http://www.google.com/search?+q=fuzzing
# The crash input is:  http:L//www.google.com/search?q=fuzzing
# The crash input is:  htdp://www.google.com/search?q=fuzzing
# The crash input is:  httpz//www.google.com/search?q=fuzzing
# The crash input is:  http:/*/www.google.com/search?q=fuzzing
# The crash input is:  ttp://www.google.com/search?q=fuzzing
# The crash input is:  ttp://www.google.com/search?q=fuzzing
# The crash input is:  http://www.google.#om/search?q=fuzzing
# The crash input is:  http://www.google.com/search?q=fuz"zing
# The crash input is:  htt://www.google.com/search?q=fuzzing
# The crash input is:  http://www.google.com/searchq=fuzzing
# The crash input is:  http://www.google.cm/search?q=fuzzing
# The crash input is:  htp://www.google.com/search?q=fuzzing
# The crash input is:  http://w)ww.google.com/search?q=fuzzing
# The crash input is:  http://ww%w.google.com/search?q=fuzzing
# The crash input is:  http://www.google.co(m/search?q=fuzzing
# The crash input is:  http://www.google.com/searchq=fuzzing
# The crash input is:  http:/:/www.google.com/search?q=fuzzing
# The crash input is:  ttp://www.google.com/search?q=fuzzing
# The crash input is:  http://www.google.com/search?q=fuzzin]g
# The crash input is:  http://www.google.com/searc\h?q=fuzzing
# The crash input is:  http:/~/www.google.com/search?q=fuzzing
# The crash input is:  http://www.google.com/search>q=fuzzing
# The crash input is:  htp://www.google.com/search?q=fuzzing
# The crash input is:  http:*//www.google.com/search?q=fuzzing
# The crash input is:  htp://www.google.com/search?q=fuzzing
# The crash input is:  http://www.gogle.com/search?q=fuzzing
# The crash input is:  http:/www.google.com/search?q=fuzzing
# The crash input is:  httHp://www.google.com/search?q=fuzzing
# The crash input is:  ttp://www.google.com/search?q=fuzzing
# The crash input is:  http:/www.google.com/search?q=fuzzing
# The crash input is:  http:/www.google.com/search?q=fuzzing
# The crash input is:  http$://www.google.com/search?q=fuzzing
# The crash input is:  http://www.google.com/search?q=fu~zing
# The crash input is:  http://www.google.com/search?q=fuzzi~g
# The crash input is:  httpG://www.google.com/search?q=fuzzing
# The crash input is:  http://wwwgoogle.com/search?q=fuzzing
# The crash input is:  `ttp://www.google.com/search?q=fuzzing
# The crash input is:  htStp://www.google.com/search?q=fuzzing
# The crash input is:  http:/www.google.com/search?q=fuzzing
# The crash input is:  http://www.google.com/search?q=fuzzi|ng
# The crash input is:  htt://www.google.com/search?q=fuzzing
# The crash input is:  htp://www.google.com/search?q=fuzzing
# The crash input is:  htdp://www.google.com/search?q=fuzzing
# The crash input is:  http://www.google.com/search?q=f}zzing
# The crash input is:  http://www.google.com/search-?q=fuzzing
# The crash input is:  http://www.google.com/search?q=fuzzing;
# The crash input is:  http://www.google.com/search?q=fuz~ing
# The crash input is:  httP://www.google.com/search?q=fuzzing
# The crash input is:  http://www.goog|e.com/search?q=fuzzing
# The crash input is:  http://www.google.com/searc`?q=fuzzing
# The crash input is:  http:/www.google.com/search?q=fuzzing
# The crash input is:  ht,tp://www.google.com/search?q=fuzzing
# The crash input is:  http:/\/www.google.com/search?q=fuzzing
# The crash input is:  htt://www.google.com/search?q=fuzzing
# The crash input is:  htEtp://www.google.com/search?q=fuzzing
# The crash input is:  1http://www.google.com/search?q=fuzzing
# The crash input is:  http://www.goog,e.com/search?q=fuzzing
# The crash input is:  http:/V/www.google.com/search?q=fuzzing
# The crash input is:  http:/www.google.com/search?q=fuzzing
# The crash input is:  htp://www.google.com/search?q=fuzzing
# The crash input is:  http//www.google.com/search?q=fuzzing
# The crash input is:  http:/>/www.google.com/search?q=fuzzing
# The crash input is:  http//www.google.com/search?q=fuzzing
# The crash input is:  http://ww.google.com/search?q=fuzzing
# The crash input is:  htp://www.google.com/search?q=fuzzing
# The crash input is:  htp://www.google.com/search?q=fuzzing
# The crash input is:  httVp://www.google.com/search?q=fuzzing
# The crash input is:  http://www.goo'le.com/search?q=fuzzing
# The crash input is:  http//www.google.com/search?q=fuzzing
# The crash input is:  http://www+.google.com/search?q=fuzzing
# The crash input is:  htt`://www.google.com/search?q=fuzzing
# The crash input is:  http://www.google.comsearch?q=fuzzing
# The crash input is:  http:/?www.google.com/search?q=fuzzing
# The crash input is:  htt://www.google.com/search?q=fuzzing
# The crash input is:  htp://www.google.com/search?q=fuzzing
# The crash input is:  http:/www.google.com/search?q=fuzzing
# The crash input is:  http://www.google.com/search?q?fuzzing
# The crash input is:  http://www.google.comsearch?q=fuzzing
# The crash input is:  http;//www.google.com/search?q=fuzzing
# The crash input is:  http://www.google.com/search?q=fuzzing+
# The crash input is:  hptp://www.google.com/search?q=fuzzing
# The crash input is:  htTp://www.google.com/search?q=fuzzing
# The crash input is:  http:/www.google.com/search?q=fuzzing
# The crash input is:  http://www.google.com/search?q=fuzzi~g
# The crash input is:  http:?/www.google.com/search?q=fuzzing
# The crash input is:  htp://www.google.com/search?q=fuzzing
# The crash input is:  http:/www.google.com/search?q=fuzzing
# The crash input is:  httIp://www.google.com/search?q=fuzzing
# The crash input is:  http//www.google.com/search?q=fuzzing
# The crash input is:  http://www.google.com/searchq=fuzzing
# The crash input is:  jttp://www.google.com/search?q=fuzzing
# The crash input is:  htp://www.google.com/search?q=fuzzing
# The crash input is:  http:/?www.google.com/search?q=fuzzing
# The crash input is:  Http://www.google.com/search?q=fuzzing
# The crash input is:  httr://www.google.com/search?q=fuzzing
# The crash input is:  http://w\ww.google.com/search?q=fuzzing
# The crash input is:  http://www.google.com/se!rch?q=fuzzing
# The crash input is:  http:I//www.google.com/search?q=fuzzing
# The crash input is:  http:/www.google.com/search?q=fuzzing
# The crash input is:  http://www.google.com/search?q=fuzzi*ng
# The crash input is:  http://ww]w.google.com/search?q=fuzzing
# The crash input is:  h|tp://www.google.com/search?q=fuzzing
# The crash input is:  htthp://www.google.com/search?q=fuzzing
# The crash input is:  http:/www.google.com/search?q=fuzzing
# The crash input is:  htp://www.google.com/search?q=fuzzing
# The crash input is:  http//www.google.com/search?q=fuzzing
# The crash input is:  http;//www.google.com/search?q=fuzzing
# The crash input is:  http://www.google.com/search?q=fuz:ing
# The crash input is:  h4tp://www.google.com/search?q=fuzzing
# The crash input is:  http://www.'google.com/search?q=fuzzing
# The crash input is:  ~http://www.google.com/search?q=fuzzing
# The crash input is:  htt://www.google.com/search?q=fuzzing
# The crash input is:  http://ww`w.google.com/search?q=fuzzing
# The crash input is:  http://www.go^ogle.com/search?q=fuzzing
# The crash input is:  htt://www.google.com/search?q=fuzzing
# The crash input is:  http://www.google.cm/search?q=fuzzing
# The crash input is:  http;//www.google.com/search?q=fuzzing
# The crash input is:  htp://www.google.com/search?q=fuzzing
# The crash input is:  http:/www.google.com/search?q=fuzzing
# The crash input is:  http:/www.google.com/search?q=fuzzing
# The crash input is:  http://www.google.com/search?q=fu zzing
# The crash input is:  lttp://www.google.com/search?q=fuzzing
# The crash input is:  ht|tp://www.google.com/search?q=fuzzing
# The crash input is:  http:://www.google.com/search?q=fuzzing
# The crash input is:  http://www.google.com/search?*q=fuzzing
# The crash input is:  http://www.google.com/search?q=fuzzi{ng
# The crash input is:  http://www.google.com/searchq=fuzzing
# The crash input is:  http://www.google.com/search;q=fuzzing
# The crash input is:  http://w~ww.google.com/search?q=fuzzing
# The crash input is:  http://www.google,com/search?q=fuzzing
# The crash input is:  http:/=/www.google.com/search?q=fuzzing
# The crash input is:  http://www.google.com'search?q=fuzzing
# The crash input is:  http://www.google.com/search?q=f,uzzing
# The crash input is:  htp://www.google.com/search?q=fuzzing
# The crash input is:  htp://www.google.com/search?q=fuzzing
# The crash input is:  http2//www.google.com/search?q=fuzzing
# The crash input is:  htt0p://www.google.com/search?q=fuzzing
# The crash input is:  http:/3/www.google.com/search?q=fuzzing
# The crash input is:  http://www.googl[e.com/search?q=fuzzing
# The crash input is:  http://www."google.com/search?q=fuzzing
# The crash input is:  http_://www.google.com/search?q=fuzzing
# The crash input is:  http://www.gogle.com/search?q=fuzzing
# The crash input is:  hYttp://www.google.com/search?q=fuzzing
# The crash input is:  http://www.google.com/searchq=fuzzing
# The crash input is:  http://www.&google.com/search?q=fuzzing
# The crash input is:  http:'/www.google.com/search?q=fuzzing
# The crash input is:  http:/www.google.com/search?q=fuzzing
# The crash input is:  htp://www.google.com/search?q=fuzzing
# The crash input is:  htdp://www.google.com/search?q=fuzzing
# The crash input is:  http://www.google.com/search7q=fuzzing
# The crash input is:  ht^tp://www.google.com/search?q=fuzzing
# The crash input is:  http://www.google.com/searc{h?q=fuzzing
# The crash input is:  http://www.google.com/{earch?q=fuzzing
# The crash input is:  http://www.google.com/search/q=fuzzing
# The crash input is:  http://www.google.c@om/search?q=fuzzing
# The crash input is:  http://www.goog"le.com/search?q=fuzzing
# The crash input is:  http://www.google.#om/search?q=fuzzing
# The crash input is:  hqttp://www.google.com/search?q=fuzzing
# The crash input is:  httt://www.google.com/search?q=fuzzing
# The crash input is:  http://www.google.comsearch?q=fuzzing
# The crash input is:  http://www,google.com/search?q=fuzzing
# The crash input is:  http://www.google.com/search?q=fuz{ing
# The crash input is:  htTp://www.google.com/search?q=fuzzing
# The crash input is:  http://www.google.com/search?q=fu{zing
# The crash input is:  http:!//www.google.com/search?q=fuzzing
# The crash input is:  http//www.google.com/search?q=fuzzing
# The crash input is:  http://;www.google.com/search?q=fuzzing
# The crash input is:  http:/#/www.google.com/search?q=fuzzing
# The crash input is:  http://www.google<.com/search?q=fuzzing
# The crash input is:  http://[www.google.com/search?q=fuzzing
# The crash input is:  http://www.google.com/search?q=fuz{ing
# The crash input is:  http://www.google.com/search?q=fuzzi.g
# The crash input is:  http>//www.google.com/search?q=fuzzing
# The crash input is:  http://www.google.com/search?q?fuzzing
# The crash input is:  http://www.goog$le.com/search?q=fuzzing
# The crash input is:  http//www.google.com/search?q=fuzzing
# The crash input is:  http://www.google.com/search?q=fu/zzing
# The crash input is:  http://www.google.com/se}arch?q=fuzzing
# The crash input is:  htp://www.google.com/search?q=fuzzing
# The crash input is:  htp://www.google.com/search?q=fuzzing
# The crash input is:  http://www.google.com/{earch?q=fuzzing
# The crash input is:  htp://www.google.com/search?q=fuzzing
# The crash input is:  http://www*google.com/search?q=fuzzing
# The crash input is:  http://www.google.com/search?{q=fuzzing
# The crash input is:  http://w*ww.google.com/search?q=fuzzing
# The crash input is:  http:/-www.google.com/search?q=fuzzing
# The crash input is:  htp://www.google.com/search?q=fuzzing
# The crash input is:  httpz//www.google.com/search?q=fuzzing
# The crash input is:  http://www.google.com/search?q=fuzzing,
# The crash input is:  http://www.google.com/searchq=fuzzing
# The crash input is:  http://www.google.com/search?q=fuzzi.g
# The crash input is:  htt?p://www.google.com/search?q=fuzzing
# The crash input is:  http://www.google*com/search?q=fuzzing
# The crash input is:  http://www>google.com/search?q=fuzzing
# The crash input is:  http://ww@w.google.com/search?q=fuzzing
# The crash input is:  http://www.google.com/search>q=fuzzing
# The crash input is:  http:/www.google.com/search?q=fuzzing
# The crash input is:  http:;//www.google.com/search?q=fuzzing
# The crash input is:  Rhttp://www.google.com/search?q=fuzzing
# The crash input is:  http://www.google.com/searchq=fuzzing
# The crash input is:  http://www.google.c>om/search?q=fuzzing
# The crash input is:  http//www.google.com/search?q=fuzzing
# The crash input is:  jttp://www.google.com/search?q=fuzzing
# The crash input is:  http://www.goog=le.com/search?q=fuzzing
# The crash input is:  http://w(ww.google.com/search?q=fuzzing
# The crash input is:  httpz//www.google.com/search?q=fuzzing
# The crash input is:  httx://www.google.com/search?q=fuzzing
# The crash input is:  http1://www.google.com/search?q=fuzzing
# The crash input is:  http://www.google.com?search?q=fuzzing
# The crash input is:  http:/www.google.com/search?q=fuzzing
# The crash input is:  http://www.google.com/search?q=f)uzzing
# The crash input is:  http:./www.google.com/search?q=fuzzing
# The crash input is:  http://www.goo>gle.com/search?q=fuzzing
# The crash input is:  Qhttp://www.google.com/search?q=fuzzing
# The crash input is:  http://www.gogle.com/search?q=fuzzing
# The crash input is:  http://www.google.com/searchq=fuzzing
# The crash input is:  xttp://www.google.com/search?q=fuzzing
# The crash input is:  htp://www.google.com/search?q=fuzzing
# The crash input is:  ttp://www.google.com/search?q=fuzzing
# The crash input is:  http://www.google.com/{earch?q=fuzzing
# The crash input is:  http://www.google.com/search?q=fuz~ing
# The crash input is:  http://www.gogle.com/search?q=fuzzing
# The crash input is:  htp://www.google.com/search?q=fuzzing
# The crash input is:  Bhttp://www.google.com/search?q=fuzzing
# The crash input is:  http:N//www.google.com/search?q=fuzzing
# The crash input is:  http://www.google.com/search7q=fuzzing
# The crash input is:  http://www.google.com/search?qfuzzing
# The crash input is:  http://www.google.com'search?q=fuzzing
# The crash input is:  http://www.goog`le.com/search?q=fuzzing
# The crash input is:  http://www.google.com/search?q=fuzz)ng
# The crash input is:  ht!tp://www.google.com/search?q=fuzzing
# The crash input is:  http://www.goo'le.com/search?q=fuzzing
# The crash input is:  http://ww.google.com/search?q=fuzzing
# The crash input is:  http://www.google.com/{earch?q=fuzzing
# The crash input is:  ttp://www.google.com/search?q=fuzzing
# The crash input is:  http:./www.google.com/search?q=fuzzing
# The crash input is:  http://www.google.com/{earch?q=fuzzing
# The crash input is:  httFp://www.google.com/search?q=fuzzing
# The crash input is:  http://www.google.cm/search?q=fuzzing
# The crash input is:  http://www.google.com/se\arch?q=fuzzing
# The crash input is:  http://www.google.com/search?q=fuz~zing
# The crash input is:  http://www.google.com/searchq=fuzzing
# The crash input is:  http//www.google.com/search?q=fuzzing
# The crash input is:  http>//www.google.com/search?q=fuzzing
# The crash input is:  http4://www.google.com/search?q=fuzzing
# The crash input is:  http://www,google.com/search?q=fuzzing
# The crash input is:  http:///www.google.com/search?q=fuzzing
# The crash input is:  http:/.www.google.com/search?q=fuzzing
# The crash input is:  htt://www.google.com/search?q=fuzzing
# The crash input is:  htt4p://www.google.com/search?q=fuzzing
# The crash input is:  http:/?www.google.com/search?q=fuzzing
# The crash input is:  htp://www.google.com/search?q=fuzzing
# The crash input is:  http://ww$w.google.com/search?q=fuzzing
# The crash input is:  httpN://www.google.com/search?q=fuzzing
# The crash input is:  http:/+www.google.com/search?q=fuzzing
# The crash input is:  http://ww.google.com/search?q=fuzzing
# The crash input is:  http://www.google.co^m/search?q=fuzzing
# The crash input is:  http://www.goo'le.com/search?q=fuzzing
# The crash input is:  http:?/www.google.com/search?q=fuzzing
# The crash input is:  htp://www.google.com/search?q=fuzzing
# The crash input is:  http://www.google.com/{earch?q=fuzzing
# The crash input is:  http://www>google.com/search?q=fuzzing
# The crash input is:  http://www.google.com#/search?q=fuzzing
# The crash input is:  http:/.www.google.com/search?q=fuzzing
# The crash input is:  http//www.google.com/search?q=fuzzing
# The crash input is:  http://www.google.com/searchq=fuzzing
# The crash input is:  hvtp://www.google.com/search?q=fuzzing
# The crash input is:  http://www.google.com/search:?q=fuzzing
# The crash input is:  http://www.google.co<m/search?q=fuzzing
# The crash input is:  http://www.google.com/search?q=fuzzin>g
# The crash input is:  http://www.google.co|m/search?q=fuzzing
# The crash input is:  http://www.google.com/searchq=fuzzing
# The crash input is:  http://www.google.cm/search?q=fuzzing
# The crash input is:  htvp://www.google.com/search?q=fuzzing
# The crash input is:  http://www.google.com/se`rch?q=fuzzing
# The crash input is:  http:/www.google.com/search?q=fuzzing
# The crash input is:  httt://www.google.com/search?q=fuzzing
# The crash input is:  http://www.google.com/search>?q=fuzzing
# The crash input is:  hBttp://www.google.com/search?q=fuzzing
# The crash input is:  httpc://www.google.com/search?q=fuzzing
# The crash input is:  htTp://www.google.com/search?q=fuzzing
# The crash input is:  htp://www.google.com/search?q=fuzzing
# The crash input is:  http:/m/www.google.com/search?q=fuzzing
# The crash input is:  http://www.googl?e.com/search?q=fuzzing
# The crash input is:  http://www.google.com?search?q=fuzzing
# The crash input is:  http://www.google.com/searchq=fuzzing
# The crash input is:  http://www.google,com/search?q=fuzzing
# The crash input is:  http://ww.google.com/search?q=fuzzing
# The crash input is:  http://www.google.com/search?q=fuzzi.g
# The crash input is:  http:E//www.google.com/search?q=fuzzing
# The crash input is:  http:/www.google.com/search?q=fuzzing
# The crash input is:  http://www.google.com/search?q=fuzz)ng
# The crash input is:  httrp://www.google.com/search?q=fuzzing
# The crash input is:  http:/^/www.google.com/search?q=fuzzing
# The crash input is:  http://www.google.com/search?q<fuzzing
# The crash input is:  htt://www.google.com/search?q=fuzzing
# The crash input is:  http:/www.google.com/search?q=fuzzing
# The crash input is:  ittp://www.google.com/search?q=fuzzing
# The crash input is:  http//www.google.com/search?q=fuzzing
# The crash input is:  http:'/www.google.com/search?q=fuzzing
# The crash input is:  hdtp://www.google.com/search?q=fuzzing
# The crash input is:  http:./www.google.com/search?q=fuzzing
# The crash input is:  ht|p://www.google.com/search?q=fuzzing
# The crash input is:  http:/www.google.com/search?q=fuzzing
# The crash input is:  http?://www.google.com/search?q=fuzzing
# The crash input is:  http://www.google.c>om/search?q=fuzzing
# The crash input is:  http://www.google.com/search?q=fu:zing
# The crash input is:  hittp://www.google.com/search?q=fuzzing
# The crash input is:  http://www.google.com/sear#h?q=fuzzing
# The crash input is:  http//www.google.com/search?q=fuzzing
# The crash input is:  htWtp://www.google.com/search?q=fuzzing
# The crash input is:  http[://www.google.com/search?q=fuzzing
# The crash input is:  http>//www.google.com/search?q=fuzzing
# The crash input is:  httPp://www.google.com/search?q=fuzzing
# The crash input is:  httPp://www.google.com/search?q=fuzzing
# The crash input is:  http://www.google.com/search?q=fuz~ing
# The crash input is:  hvttp://www.google.com/search?q=fuzzing
# The crash input is:  http:/'www.google.com/search?q=fuzzing
# The crash input is:  http:/7/www.google.com/search?q=fuzzing
# The crash input is:  htdp://www.google.com/search?q=fuzzing
# The crash input is:  http://www.google.com/?search?q=fuzzing
# The crash input is:  http://ww.google.com/search?q=fuzzing
# The crash input is:  http://www.google.com/searchq=fuzzing
# The crash input is:  htt://www.google.com/search?q=fuzzing
# The crash input is:  http://www.google.com/search?q<fuzzing
# The crash input is:  hnttp://www.google.com/search?q=fuzzing
# The crash input is:  ittp://www.google.com/search?q=fuzzing
# The crash input is:  http://ww,w.google.com/search?q=fuzzing
# The crash input is:  http://www.google.com/search~?q=fuzzing
# The crash input is:  http://www.googl?e.com/search?q=fuzzing
# The crash input is:  httr://www.google.com/search?q=fuzzing
# The crash input is:  http*://www.google.com/search?q=fuzzing
# The crash input is:  htt://www.google.com/search?q=fuzzing
# The crash input is:  http://\www.google.com/search?q=fuzzing
# The crash input is:  http://www.google.com/search?q=fuzzi"ng
# The crash input is:  http://www.google.com/search?q=fu{zing
# The crash input is:  htOtp://www.google.com/search?q=fuzzing
# The crash input is:  http:/www.google.com/search?q=fuzzing
# The crash input is:  hmttp://www.google.com/search?q=fuzzing
# The crash input is:  hptp://www.google.com/search?q=fuzzing
# The crash input is:  http://www.google.com/s@earch?q=fuzzing
# The crash input is:  http://www.google^.com/search?q=fuzzing
# The crash input is:  http://www.google.com/searchq=fuzzing
# The crash input is:  http://www.google.com'search?q=fuzzing
# The crash input is:  http//www.google.com/search?q=fuzzing
# The crash input is:  htt://www.google.com/search?q=fuzzing
# The crash input is:  http://www.google.com/search[?q=fuzzing
# The crash input is:  `ttp://www.google.com/search?q=fuzzing
# The crash input is:  http://www.google.com/search?q=fuzzing$
# The crash input is:  http://www&google.com/search?q=fuzzing
# The crash input is:  http//www.google.com/search?q=fuzzing
# The crash input is:   http://www.google.com/search?q=fuzzing
# The crash input is:  http://www.google.com/search?q=f@uzzing
# The crash input is:  http!://www.google.com/search?q=fuzzing
# The crash input is:  htt://www.google.com/search?q=fuzzing
# The crash input is:  htt0://www.google.com/search?q=fuzzing
# The crash input is:  http://www.google.com/search?q=fuzzi)ng
# The crash input is:  http:/www.google.com/search?q=fuzzing
# The crash input is:  http://www.google.com/s*earch?q=fuzzing
# The crash input is:  http//www.google.com/search?q=fuzzing
# The crash input is:  http://www.google&com/search?q=fuzzing
# The crash input is:  ttp://www.google.com/search?q=fuzzing
# The crash input is:  http://www.google.com/searchq=fuzzing
# The crash input is:  htt://www.google.com/search?q=fuzzing
# The crash input is:  http;//www.google.com/search?q=fuzzing
# The crash input is:  htbtp://www.google.com/search?q=fuzzing
# The crash input is:  htdp://www.google.com/search?q=fuzzing
# The crash input is:  http://www.goog\le.com/search?q=fuzzing
# The crash input is:  http:/www.google.com/search?q=fuzzing
# The crash input is:  http://wwwgoogle.com/search?q=fuzzing
# The crash input is:  http:///www.google.com/search?q=fuzzing
# The crash input is:  http://>www.google.com/search?q=fuzzing
# The crash input is:  http://www.google.com/se!rch?q=fuzzing
# The crash input is:  http:/www.google.com/search?q=fuzzing
# The crash input is:  http:/+/www.google.com/search?q=fuzzing
# The crash input is:  http://www.google.com/s*earch?q=fuzzing
# The crash input is:  httt://www.google.com/search?q=fuzzing
# The crash input is:  htp://www.google.com/search?q=fuzzing
# The crash input is:  http//www.google.com/search?q=fuzzing
# The crash input is:  http<://www.google.com/search?q=fuzzing
# The crash input is:  http://www.google.com+search?q=fuzzing
# The crash input is:  hutp://www.google.com/search?q=fuzzing
# The crash input is:  http//www.google.com/search?q=fuzzing
# The crash input is:  http://www.go#ogle.com/search?q=fuzzing
# The crash input is:  http://www.google.co+m/search?q=fuzzing
# The crash input is:  htp://www.google.com/search?q=fuzzing
# The crash input is:  http//www.google.com/search?q=fuzzing
# The crash input is:  http://www.google.com/{earch?q=fuzzing
# The crash input is:  http://www.google.com/search?q=fuz@zing
# The crash input is:  http:/www.google.com/search?q=fuzzing
# The crash input is:  Http://www.google.com/search?q=fuzzing
# The crash input is:  ttp://www.google.com/search?q=fuzzing
# The crash input is:  htp://www.google.com/search?q=fuzzing
# The crash input is:  hOttp://www.google.com/search?q=fuzzing
# The crash input is:  http://www.google.com/search?q=fuz~ing
# The crash input is:  htp://www.google.com/search?q=fuzzing
# The crash input is:  http://www.google.com/search'?q=fuzzing
# The crash input is:  http://www.google.com/search?q=fu:zing
# The crash input is:  http://w;ww.google.com/search?q=fuzzing
# The crash input is:  http:-/www.google.com/search?q=fuzzing
# The crash input is:  http://^www.google.com/search?q=fuzzing
# The crash input is:  httpU://www.google.com/search?q=fuzzing
# The crash input is:  httSp://www.google.com/search?q=fuzzing
# The crash input is:  htt://www.google.com/search?q=fuzzing
# The crash input is:  htt|p://www.google.com/search?q=fuzzing
# The crash input is:  h|ttp://www.google.com/search?q=fuzzing
# The crash input is:  }http://www.google.com/search?q=fuzzing
# The crash input is:  http://www.^google.com/search?q=fuzzing
# The crash input is:  http:/www.google.com/search?q=fuzzing
# The crash input is:  httt://www.google.com/search?q=fuzzing
# The crash input is:  httr://www.google.com/search?q=fuzzing
# The crash input is:  h.ttp://www.google.com/search?q=fuzzing
# The crash input is:  h4tp://www.google.com/search?q=fuzzing
# The crash input is:  http://'www.google.com/search?q=fuzzing
# The crash input is:  http://www.google.com/se'arch?q=fuzzing
# The crash input is:  `ttp://www.google.com/search?q=fuzzing
# The crash input is:  http://www.google.com/search?q=fu:zing
# The crash input is:  http://www.google.com/sea[rch?q=fuzzing
# The crash input is:  http://www.google.com/searchq=fuzzing
# The crash input is:  httpz//www.google.com/search?q=fuzzing
# The crash input is:  http:X//www.google.com/search?q=fuzzing
# The crash input is:  http:E//www.google.com/search?q=fuzzing
# The crash input is:  httGp://www.google.com/search?q=fuzzing
# The crash input is:  http:://www.google.com/search?q=fuzzing
# The crash input is:  http://www.goog?le.com/search?q=fuzzing
# The crash input is:  http://www.google.co,m/search?q=fuzzing
# The crash input is:  jttp://www.google.com/search?q=fuzzing
# The crash input is:  http://www.google.co<m/search?q=fuzzing
# The crash input is:  jttp://www.google.com/search?q=fuzzing
# The crash input is:  http:A//www.google.com/search?q=fuzzing
# The crash input is:  http://www>google.com/search?q=fuzzing
# The crash input is:  h8ttp://www.google.com/search?q=fuzzing
# The crash input is:  http:/www.google.com/search?q=fuzzing
# The crash input is:  h$ttp://www.google.com/search?q=fuzzing
# The crash input is:  http://www.google.com+search?q=fuzzing
# The crash input is:  http//www.google.com/search?q=fuzzing
# The crash input is:  htp://www.google.com/search?q=fuzzing
# The crash input is:  http://www>google.com/search?q=fuzzing
# The crash input is:  http://www.google.com/searchq=fuzzing
# The crash input is:  http://wwwgoogle.com/search?q=fuzzing
# The crash input is:  http;//www.google.com/search?q=fuzzing
# The crash input is:  http://www.google&com/search?q=fuzzing
# The crash input is:  xttp://www.google.com/search?q=fuzzing
# The crash input is:  htktp://www.google.com/search?q=fuzzing
# The crash input is:  htt://www.google.com/search?q=fuzzing
# The crash input is:  zhttp://www.google.com/search?q=fuzzing
# The crash input is:  http://www.google,com/search?q=fuzzing
# The crash input is:  http:N//www.google.com/search?q=fuzzing
# The crash input is:  httpc://www.google.com/search?q=fuzzing
# The crash input is:  http://www.google.co!m/search?q=fuzzing
# The crash input is:  http://www.google.com/search?q=fuzzi;ng
# The crash input is:  htJtp://www.google.com/search?q=fuzzing
# The crash input is:  h{ttp://www.google.com/search?q=fuzzing
# The crash input is:  ttp://www.google.com/search?q=fuzzing
# The crash input is:  http://www.google.:com/search?q=fuzzing
# The crash input is:  http:/www.google.com/search?q=fuzzing
# The crash input is:  http://www.google.com/searchq=fuzzing
# The crash input is:  http://ww+w.google.com/search?q=fuzzing
# The crash input is:  http://www*google.com/search?q=fuzzing
# The crash input is:  http:/www.google.com/search?q=fuzzing
# The crash input is:  htt://www.google.com/search?q=fuzzing
# The crash input is:  jttp://www.google.com/search?q=fuzzing
# The crash input is:  http://www.google.com/search?q=f|uzzing
# The crash input is:  http://www.google>com/search?q=fuzzing
# The crash input is:  http://www,google.com/search?q=fuzzing
# The crash input is:  http://www.google.com/search?q=fuzz)ng
# The crash input is:  `ttp://www.google.com/search?q=fuzzing
# The crash input is:  http://www.googl e.com/search?q=fuzzing
# The crash input is:  http://www.google.co}/search?q=fuzzing
# The crash input is:  http://www.googl+e.com/search?q=fuzzing
# The crash input is:  http:///www.google.com/search?q=fuzzing
# The crash input is:  http://www.google.c[om/search?q=fuzzing
# The crash input is:  http8//www.google.com/search?q=fuzzing
# The crash input is:  hutp://www.google.com/search?q=fuzzing
# The crash input is:  http://www.google.com/search>q=fuzzing
# The crash input is:  httpd://www.google.com/search?q=fuzzing
# The crash input is:  http://www.google.co}/search?q=fuzzing
# The crash input is:  http://www.google.co$m/search?q=fuzzing
# The crash input is:  htp://www.google.com/search?q=fuzzing
# The crash input is:  http://www.google.com/search?q=fu`zzing
# The crash input is:  http:/www.google.com/search?q=fuzzing
# The crash input is:  ttp://www.google.com/search?q=fuzzing
# The crash input is:  http://www.google.com/sear#h?q=fuzzing
# The crash input is:  http://www.google.co}m/search?q=fuzzing
# The crash input is:  ttp://www.google.com/search?q=fuzzing
# The crash input is:  http//www.google.com/search?q=fuzzing
# The crash input is:  http://www.google.com/search?\q=fuzzing
# The crash input is:  htp://www.google.com/search?q=fuzzing
# The crash input is:  hzttp://www.google.com/search?q=fuzzing
# The crash input is:  http:/o/www.google.com/search?q=fuzzing
# The crash input is:  ht>tp://www.google.com/search?q=fuzzing
# The crash input is:  http://www.google.com/s`earch?q=fuzzing
# The crash input is:  http://www.googl%.com/search?q=fuzzing
# The crash input is:  http://www.google.com/search7q=fuzzing
# The crash input is:  http://www.google.com/search?q=fuzzi@ng
# The crash input is:  http://www.google.com/search?q=fuz\zing
# The crash input is:  http:/S/www.google.com/search?q=fuzzing
# The crash input is:  http:/ /www.google.com/search?q=fuzzing
# The crash input is:  0http://www.google.com/search?q=fuzzing
# The crash input is:  http:/www.google.com/search?q=fuzzing
# The crash input is:  http://www.google&com/search?q=fuzzing
# The crash input is:  http://www.google.com'search?q=fuzzing
# The crash input is:  `ttp://www.google.com/search?q=fuzzing
# The crash input is:  http://www.google.com/search?q=fuzzin}g
# The crash input is:  htPtp://www.google.com/search?q=fuzzing
# The crash input is:  http://www.goog,e.com/search?q=fuzzing
# The crash input is:  htp://www.google.com/search?q=fuzzing
# The crash input is:  http*://www.google.com/search?q=fuzzing
# The crash input is:  http://www.google.com/search?q?fuzzing
# The crash input is:  httpy://www.google.com/search?q=fuzzing
# The crash input is:  htt://www.google.com/search?q=fuzzing
# The crash input is:  http://www.google,com/search?q=fuzzing
# The crash input is:  http://www.google.com/search;q=fuzzing
# The crash input is:  ahttp://www.google.com/search?q=fuzzing
# The crash input is:  httx://www.google.com/search?q=fuzzing
# The crash input is:  http://www.google.com/s%arch?q=fuzzing
# The crash input is:  http://www.google.com'search?q=fuzzing
# The crash input is:  http://www.google.cm/search?q=fuzzing
# The crash input is:  h7ttp://www.google.com/search?q=fuzzing
# The crash input is:  http://www.google.com/search?qfuzzing
# The crash input is:  hvtp://www.google.com/search?q=fuzzing
# The crash input is:  htpp://www.google.com/search?q=fuzzing
# The crash input is:  http://www.google.com/se%arch?q=fuzzing
# The crash input is:  http:'/www.google.com/search?q=fuzzing
# The crash input is:  http://w&ww.google.com/search?q=fuzzing
# The crash input is:  htp://www.google.com/search?q=fuzzing
# The crash input is:  http:/~/www.google.com/search?q=fuzzing
# The crash input is:  http://www.google.com/search?q=fuzzi~g
# The crash input is:  httpd://www.google.com/search?q=fuzzing
# The crash input is:  http://www.google.com/search=q=fuzzing
# The crash input is:  http:/www.google.com/search?q=fuzzing
# The crash input is:  http:'//www.google.com/search?q=fuzzing
# The crash input is:  ttp://www.google.com/search?q=fuzzing
# The crash input is:  http://www.google.com/search?q?fuzzing
# The crash input is:  http:/d/www.google.com/search?q=fuzzing
# The crash input is:  http://www.google.com/sear#h?q=fuzzing
# The crash input is:  htt0://www.google.com/search?q=fuzzing
# The crash input is:  xttp://www.google.com/search?q=fuzzing
# The crash input is:  http://www.google.com/searchq=fuzzing
# The crash input is:  `ttp://www.google.com/search?q=fuzzing
# The crash input is:  http://www.google.com/searc`?q=fuzzing
# The crash input is:  http;//www.google.com/search?q=fuzzing
# The crash input is:  http://www.google.com/searc`?q=fuzzing
# The crash input is:  http:/www.google.com/search?q=fuzzing
# The crash input is:  ttp://www.google.com/search?q=fuzzing
# The crash input is:  vhttp://www.google.com/search?q=fuzzing
# The crash input is:  http://www.google.com/search7q=fuzzing
# The crash input is:  http://www.google.com/sear#h?q=fuzzing
# The crash input is:  httpK://www.google.com/search?q=fuzzing
# The crash input is:  http://www.google.com/search?q<fuzzing
# The crash input is:  htt://www.google.com/search?q=fuzzing
# The crash input is:  http://www.google.com/search?q=fuz(zing
# The crash input is:  http//www.google.com/search?q=fuzzing
# The crash input is:  hvtp://www.google.com/search?q=fuzzing
# The crash input is:  htt`://www.google.com/search?q=fuzzing
# The crash input is:  http://www.google.com/s!earch?q=fuzzing
# The crash input is:  http://www.google.com+search?q=fuzzing
# The crash input is:  http://www.google.com/search?q=fuz~ing
# The crash input is:  http://www.google.com/search?q<fuzzing
# The crash input is:  http://www.google,com/search?q=fuzzing
# The crash input is:  http://www.googl[e.com/search?q=fuzzing
# The crash input is:  htp://www.google.com/search?q=fuzzing
# The crash input is:  hSttp://www.google.com/search?q=fuzzing
# The crash input is:  hTtp://www.google.com/search?q=fuzzing
# The crash input is:  httSp://www.google.com/search?q=fuzzing
# The crash input is:  http://www.google.com/[search?q=fuzzing
# The crash input is:  http:/www.google.com/search?q=fuzzing
# The crash input is:  http://www.google.com/search?q=fuzzin}g
# The crash input is:  ttp://www.google.com/search?q=fuzzing
# The crash input is:  http:/V/www.google.com/search?q=fuzzing
# The crash input is:  http://www.{google.com/search?q=fuzzing
# The crash input is:  `ttp://www.google.com/search?q=fuzzing
# The crash input is:  `ttp://www.google.com/search?q=fuzzing
# The crash input is:  (ttp://www.google.com/search?q=fuzzing
# The crash input is:  http://www.google.com/search?qfuzzing
# The crash input is:  http://www.google.com/search7q=fuzzing
# The crash input is:  http://www.google.co[m/search?q=fuzzing
# The crash input is:  http:/owww.google.com/search?q=fuzzing
# The crash input is:  hutp://www.google.com/search?q=fuzzing
# The crash input is:  htp://www.google.com/search?q=fuzzing
# The crash input is:  http://www.google.com/searchq=fuzzing
# The crash input is:  http://www.google.co}/search?q=fuzzing
# The crash input is:  http:/ /www.google.com/search?q=fuzzing
# The crash input is:  http://www.(google.com/search?q=fuzzing
# The crash input is:  http://www.'oogle.com/search?q=fuzzing
# The crash input is:  http://www.google.com/search?q=fuzzi~g
# The crash input is:  htt://www.google.com/search?q=fuzzing
# The crash input is:  http:/M/www.google.com/search?q=fuzzing
# The crash input is:  hFttp://www.google.com/search?q=fuzzing
# The crash input is:  http:/'www.google.com/search?q=fuzzing
# The crash input is:  http://www.google.com/search?q=fuzz?ing
# The crash input is:  http://www.google.com/sear@ch?q=fuzzing
# The crash input is:  http://www.goog,e.com/search?q=fuzzing
# ...
# The crash input is:  http://www.google.com/search?$q=fuzzing
# The crash input is:  http://www.goo<gle.com/search?q=fuzzing
# The crash input is:  http://www.google.com/search?q=}fuzzing
# The crash input is:  http://www.google,com/search?q=fuzzing
# The crash input is:  httSp://www.google.com/search?q=fuzzing
# The crash input is:  http://www.google.com/search?q=fuzzin'g
# The crash input is:  http:'/www.google.com/search?q=fuzzing
# The crash input is:  httcp://www.google.com/search?q=fuzzing
# The crash input is:  http://www.goog|e.com/search?q=fuzzing
# The crash input is:  http://www.g!oogle.com/search?q=fuzzing
# The crash input is:  http://www.google.com/searchq=fuzzing
# The crash input is:  lttp://www.google.com/search?q=fuzzing
# The crash input is:  http://www.google.com/search?q=f[uzzing
# The crash input is:  http://www.google.#om/search?q=fuzzing
# The crash input is:  htp://www.google.com/search?q=fuzzing
# The crash input is:  htt://www.google.com/search?q=fuzzing
# The crash input is:  http://www.google.com/search?q=fuz{ing
# The crash input is:  http://www.google.com/search?qfuzzing
# The crash input is:  http://w}ww.google.com/search?q=fuzzing
# The crash input is:  http://www.google.com/search?q=fu{zing
# The crash input is:  http://www*google.com/search?q=fuzzing
# The crash input is:  http://www.google.com/searc@h?q=fuzzing
# The crash input is:  httpQ://www.google.com/search?q=fuzzing
# The crash input is:  http://www.google.com/search?qfuzzing
# The crash input is:  http://ww<w.google.com/search?q=fuzzing
# The crash input is:  http://www.google.com/searchq=fuzzing
# The crash input is:  http://www.google>com/search?q=fuzzing
# The crash input is:  htp://www.google.com/search?q=fuzzing
# The crash input is:  http:N//www.google.com/search?q=fuzzing
# The crash input is:  ttp://www.google.com/search?q=fuzzing
# The crash input is:  hdtp://www.google.com/search?q=fuzzing
# The crash input is:  http://www.google.c#om/search?q=fuzzing
# The crash input is:  httAp://www.google.com/search?q=fuzzing
# The crash input is:  http://www.google.com/search?q=fuzz|ing
# The crash input is:  http://www.google.com/search?q=fu:zing
# The crash input is:  http://www.google.com/searchq=fuzzing
# The crash input is:  http://www.google.com/search>q=fuzzing
# The crash input is:  htt://www.google.com/search?q=fuzzing
# The crash input is:  ttp://www.google.com/search?q=fuzzing
# The crash input is:  http://www.google.com/search;q=fuzzing
# The crash input is:  htt0://www.google.com/search?q=fuzzing
# The crash input is:  httup://www.google.com/search?q=fuzzing
# The crash input is:  http:o/www.google.com/search?q=fuzzing
# The crash input is:  http//www.google.com/search?q=fuzzing
# The crash input is:  http://www.goog'le.com/search?q=fuzzing
# The crash input is:  http8//www.google.com/search?q=fuzzing
# The crash input is:  hTtp://www.google.com/search?q=fuzzing
# The crash input is:  http://ww.google.com/search?q=fuzzing
# The crash input is:  http://www.google.com/search?q=,fuzzing
# The crash input is:  http://ww.google.com/search?q=fuzzing
# The crash input is:  htp://www.google.com/search?q=fuzzing
# The crash input is:  htt`://www.google.com/search?q=fuzzing
# The crash input is:  htt://www.google.com/search?q=fuzzing
# The crash input is:  http://www.g`oogle.com/search?q=fuzzing
# The crash input is:  http://www.google.com/se`rch?q=fuzzing
# The crash input is:  http://www.google.com/sear+ch?q=fuzzing
# The crash input is:  http://www.googl`e.com/search?q=fuzzing
# The crash input is:  http:/www.google.com/search?q=fuzzing
# The crash input is:  http://www.google.com/searchq=fuzzing
# The crash input is:  http://w^ww.google.com/search?q=fuzzing
# The crash input is:  http://www.%google.com/search?q=fuzzing
# The crash input is:  http://www.google.com/search?q<fuzzing
# The crash input is:  http://www.google.com/search?qfuzzing
# The crash input is:  http:/www.google.com/search?q=fuzzing
# The crash input is:  http://www.'oogle.com/search?q=fuzzing
# The crash input is:  h7ttp://www.google.com/search?q=fuzzing
# The crash input is:  ttp://www.google.com/search?q=fuzzing
# The crash input is:  http:/.www.google.com/search?q=fuzzing
# The crash input is:  http://www.google.com/se\arch?q=fuzzing
# The crash input is:  http://www>google.com/search?q=fuzzing
# The crash input is:  http://www.google.&com/search?q=fuzzing
# The crash input is:  http://www.google.com/search?q=?fuzzing
# The crash input is:  ttp://www.google.com/search?q=fuzzing
# The crash input is:  http://www+.google.com/search?q=fuzzing
# The crash input is:  http://www.google.com/searchq=fuzzing
# The crash input is:  http://www.google.com/searchq=fuzzing
# The crash input is:  http://www.google.com/searchq=fuzzing
# The crash input is:  http://www>google.com/search?q=fuzzing
# The crash input is:  http://www.google.com/search?q=fuzz|ing
# The crash input is:  http://www.google.*com/search?q=fuzzing
# The crash input is:  htp://www.google.com/search?q=fuzzing
# The crash input is:  _http://www.google.com/search?q=fuzzing
# The crash input is:  ,http://www.google.com/search?q=fuzzing
# The crash input is:  httx://www.google.com/search?q=fuzzing
# The crash input is:  http://www.google.com/search'?q=fuzzing
# The crash input is:  http://www.google.com/searchq=fuzzing
# The crash input is:  http://www.google>com/search?q=fuzzing
# The crash input is:  ttp://www.google.com/search?q=fuzzing
# The crash input is:  ht2tp://www.google.com/search?q=fuzzing
# The crash input is:  http:/.www.google.com/search?q=fuzzing
# The crash input is:  http://www.google.cm/search?q=fuzzing
# The crash input is:  ttp://www.google.com/search?q=fuzzing
# The crash input is:  http://www.google.com/se~arch?q=fuzzing
# The crash input is:  hLttp://www.google.com/search?q=fuzzing
# The crash input is:  http:/*/www.google.com/search?q=fuzzing
# The crash input is:  http://www.google.com/search?q={fuzzing
# The crash input is:  ht|p://www.google.com/search?q=fuzzing
# The crash input is:  http:/C/www.google.com/search?q=fuzzing
# The crash input is:  http://wwwgoogle.com/search?q=fuzzing
# The crash input is:  http://www.google.com/search?q=fuzz)ng
# The crash input is:  http://www.google.}com/search?q=fuzzing
# The crash input is:  hyttp://www.google.com/search?q=fuzzing
# The crash input is:  htt://www.google.com/search?q=fuzzing
# The crash input is:  http://www.google&.com/search?q=fuzzing
# The crash input is:  http://www.goo)gle.com/search?q=fuzzing
# The crash input is:  htp://www.google.com/search?q=fuzzing
# The crash input is:  http://www.google.com/sea:rch?q=fuzzing
# The crash input is:  http://www.google.com/searc:h?q=fuzzing
# The crash input is:  http://www.googlecom/search?q=fuzzing
# The crash input is:  http://www.goo gle.com/search?q=fuzzing
# The crash input is:  http://ww.google.com/search?q=fuzzing
# The crash input is:  http://www.google.com/search?q=fuzzi~g
# The crash input is:  htt`://www.google.com/search?q=fuzzing
# The crash input is:  h|tp://www.google.com/search?q=fuzzing
# The crash input is:  http:r//www.google.com/search?q=fuzzing
# The crash input is:  http:/'www.google.com/search?q=fuzzing
# The crash input is:  Phttp://www.google.com/search?q=fuzzing
# The crash input is:  http://www.google.com/search>q=fuzzing
# The crash input is:  htp://www.google.com/search?q=fuzzing
# The crash input is:  http://www.google.com/searc\h?q=fuzzing
# The crash input is:  htp://www.google.com/search?q=fuzzing
# The crash input is:  hutp://www.google.com/search?q=fuzzing
# The crash input is:  http://www.go]ogle.com/search?q=fuzzing
# The crash input is:  http://www.google.com/\search?q=fuzzing
# The crash input is:  http://www.google.com/searchq=fuzzing
# The crash input is:  http://www.google.#om/search?q=fuzzing
# The crash input is:  http://www.g|oogle.com/search?q=fuzzing
# The crash input is:  http://www.google*com/search?q=fuzzing
# The crash input is:  hXttp://www.google.com/search?q=fuzzing
# The crash input is:  http://www.g=oogle.com/search?q=fuzzing
# The crash input is:  http://www.google.com/s]earch?q=fuzzing
# The crash input is:  http://www.google.com/searc(?q=fuzzing
# The crash input is:  htt://www.google.com/search?q=fuzzing
# The crash input is:  http:/www.google.com/search?q=fuzzing
# The crash input is:  htp://www.google.com/search?q=fuzzing
# The crash input is:  http://ww.google.com/search?q=fuzzing
# The crash input is:  lttp://www.google.com/search?q=fuzzing
# The crash input is:  http://www.google.com/searchq=fuzzing
# The crash input is:  http:A//www.google.com/search?q=fuzzing
# The crash input is:  http://www.google.co=m/search?q=fuzzing
# The crash input is:  htvp://www.google.com/search?q=fuzzing
# The crash input is:  http://www.go+ogle.com/search?q=fuzzing
# The crash input is:  htp://www.google.com/search?q=fuzzing
# The crash input is:  ht+tp://www.google.com/search?q=fuzzing
# The crash input is:  http://www.google.com/search;q=fuzzing
# The crash input is:  http//www.google.com/search?q=fuzzing
# The crash input is:  http://www.google.com/search?q'=fuzzing
# The crash input is:  http://www.google.cm/search?q=fuzzing
# The crash input is:  ttp://www.google.com/search?q=fuzzing
# The crash input is:  htt://www.google.com/search?q=fuzzing
# The crash input is:  hutp://www.google.com/search?q=fuzzing
# The crash input is:  http://www.google.com/search?q<fuzzing
# The crash input is:  h#ttp://www.google.com/search?q=fuzzing
# The crash input is:  http://www.google.com/s~earch?q=fuzzing
# The crash input is:  http://www.google.com/searchq=fuzzing
# The crash input is:  htNtp://www.google.com/search?q=fuzzing
# The crash input is:  http:/.www.google.com/search?q=fuzzing
# The crash input is:  http://www.googl!e.com/search?q=fuzzing
# The crash input is:  http:/www.google.com/search?q=fuzzing
# The crash input is:  http://www.google.com/search?q=|fuzzing
# The crash input is:  h4tp://www.google.com/search?q=fuzzing
# The crash input is:  http://www.google.com/search?q=fu)zzing
# The crash input is:  http://www.google.com/search?q=:fuzzing
# The crash input is:  |http://www.google.com/search?q=fuzzing
# The crash input is:  http://www.goog,e.com/search?q=fuzzing
# The crash input is:  httpz//www.google.com/search?q=fuzzing
# The crash input is:  http://www.google.com/search/q=fuzzing
# The crash input is:  hLttp://www.google.com/search?q=fuzzing
# The crash input is:  http://www.google.com/searchq=fuzzing
# The crash input is:  http:/f/www.google.com/search?q=fuzzing
# The crash input is:  http:/www.google.com/search?q=fuzzing
# The crash input is:  httBp://www.google.com/search?q=fuzzing
# The crash input is:  htpp://www.google.com/search?q=fuzzing
# The crash input is:  htp://www.google.com/search?q=fuzzing
# The crash input is:  http://www.gogle.com/search?q=fuzzing
# The crash input is:  http://www.google.com/search?q=fuz{ing
# The crash input is:  ttp://www.google.com/search?q=fuzzing
# The crash input is:  lttp://www.google.com/search?q=fuzzing
# The crash input is:  http://www.google.com/sear`ch?q=fuzzing
# The crash input is:  httpP://www.google.com/search?q=fuzzing
# The crash input is:  http://www.google.com/search?q?fuzzing
# The crash input is:  http:://www.google.com/search?q=fuzzing
# The crash input is:  http://www.google.com/search?q=fuz]zing
# The crash input is:  http://www.google.com/s~earch?q=fuzzing
# The crash input is:  ttp://www.google.com/search?q=fuzzing
# The crash input is:  http://www.google.com/searc`?q=fuzzing
# The crash input is:  ttp://www.google.com/search?q=fuzzing
# The crash input is:  ttp://www.google.com/search?q=fuzzing
# The crash input is:  httpp://www.google.com/search?q=fuzzing
# The crash input is:  http:6//www.google.com/search?q=fuzzing
# The crash input is:  http://www.google.com/search{?q=fuzzing
# The crash input is:  http:>//www.google.com/search?q=fuzzing
# The crash input is:  http://www.g;oogle.com/search?q=fuzzing
# The crash input is:  http://www.google.com/search?q=fu{zing
# The crash input is:  http://ww.google.com/search?q=fuzzing
# The crash input is:  http://www.google.com/sea}rch?q=fuzzing
# The crash input is:  http://www.google.com/searc@h?q=fuzzing
# The crash input is:  Qhttp://www.google.com/search?q=fuzzing
# The crash input is:  htp://www.google.com/search?q=fuzzing
# The crash input is:  http:/www.google.com/search?q=fuzzing
# The crash input is:  http://www.google.com/se+arch?q=fuzzing
# The crash input is:  http:/www.google.com/search?q=fuzzing
# The crash input is:  http://www.google.com/search?q<fuzzing
# The crash input is:  http//www.google.com/search?q=fuzzing
# The crash input is:  http;//www.google.com/search?q=fuzzing
# The crash input is:  http://www.google.com/search?q=fuz{ing
# The crash input is:  http://www.google.com/search>q=fuzzing
# The crash input is:  http://www.google.com/{earch?q=fuzzing
# The crash input is:  lttp://www.google.com/search?q=fuzzing
# The crash input is:  Yhttp://www.google.com/search?q=fuzzing
# The crash input is:  http//www.google.com/search?q=fuzzing
# The crash input is:  http://www.google.com/sear=ch?q=fuzzing
# The crash input is:  http://www.google.com/sea,rch?q=fuzzing
# The crash input is:  htt1p://www.google.com/search?q=fuzzing
# The crash input is:  hnttp://www.google.com/search?q=fuzzing
# The crash input is:  http;//www.google.com/search?q=fuzzing
# The crash input is:  ht-tp://www.google.com/search?q=fuzzing
# The crash input is:  http://www.google.com/search?q<fuzzing
# The crash input is:  htttp://www.google.com/search?q=fuzzing
# The crash input is:  http://www.google>com/search?q=fuzzing
# The crash input is:  http://www.google.co'm/search?q=fuzzing
# The crash input is:  httYp://www.google.com/search?q=fuzzing
# The crash input is:  http://www.google.com/{earch?q=fuzzing
# The crash input is:  http:+/www.google.com/search?q=fuzzing
# The crash input is:  http://www.google.com/sear=ch?q=fuzzing
# The crash input is:  htt://www.google.com/search?q=fuzzing
# The crash input is:  http://www.google.com/se}arch?q=fuzzing
# The crash input is:  http://www.google>com/search?q=fuzzing
# The crash input is:  http@://www.google.com/search?q=fuzzing
# The crash input is:  htt://www.google.com/search?q=fuzzing
# The crash input is:  http://www.google.com/search?q=}fuzzing
# The crash input is:  http:/?www.google.com/search?q=fuzzing
# The crash input is:  http://www.gogle.com/search?q=fuzzing
# The crash input is:  htdp://www.google.com/search?q=fuzzing
# The crash input is:  http://www.google.com]/search?q=fuzzing
# The crash input is:  http://www.google.com/search?%q=fuzzing
# The crash input is:  http:/2/www.google.com/search?q=fuzzing
# The crash input is:  htp://www.google.com/search?q=fuzzing
# The crash input is:  http://www.google.cm/search?q=fuzzing
# The crash input is:  htp://www.google.com/search?q=fuzzing
# The crash input is:  htttp://www.google.com/search?q=fuzzing
# The crash input is:  http;//www.google.com/search?q=fuzzing
# The crash input is:  hPttp://www.google.com/search?q=fuzzing
# The crash input is:  http://www.google.com/search?q<fuzzing
# The crash input is:  htvp://www.google.com/search?q=fuzzing
# The crash input is:  Http://www.google.com/search?q=fuzzing
# The crash input is:  http://www.google.com/search?!q=fuzzing
# The crash input is:  http:/b/www.google.com/search?q=fuzzing
# The crash input is:  http://www.goo'le.com/search?q=fuzzing
# The crash input is:  http://www.g@oogle.com/search?q=fuzzing
# The crash input is:  hdtp://www.google.com/search?q=fuzzing
# The crash input is:  http:/*/www.google.com/search?q=fuzzing
# The crash input is:  http:<//www.google.com/search?q=fuzzing
# The crash input is:  htp://www.google.com/search?q=fuzzing
# The crash input is:  http:/f/www.google.com/search?q=fuzzing
# The crash input is:  http://www.google.com/search?qfuzzing
# The crash input is:  3http://www.google.com/search?q=fuzzing
# The crash input is:  ttp://www.google.com/search?q=fuzzing
# The crash input is:  http:/+www.google.com/search?q=fuzzing
# The crash input is:  http:/www.google.com/search?q=fuzzing
# The crash input is:  htt`://www.google.com/search?q=fuzzing
# The crash input is:  http://ww<w.google.com/search?q=fuzzing
# The crash input is:  http://www.google.com/sear(ch?q=fuzzing
# The crash input is:  Zhttp://www.google.com/search?q=fuzzing
# The crash input is:  http//www.google.com/search?q=fuzzing
# The total crash count is:  3543
